# %% [markdown]
# # Mais sobre `SELECT`
#
# - temporary tables
# - views
# - variables
# - subqueries

# %%
import mysql.connector
from functools import partial


def get_connection_helper():

    def run_db_query(connection, query, args=None):
        with connection.cursor() as cursor:
            print('Executando query:')
            cursor.execute(query, args)
            for result in cursor:
                print(result)

    connection = mysql.connector.connect(
        host='localhost',
        user='megadados',
        password='megadados',
        database='sakila',
    )
    return connection, partial(run_db_query, connection)


connection, db = get_connection_helper()

# %% [markdown]
# ## Aquecimento

# %% [markdown]
# Quanta receita foi gerada para cada categoria de filmes? Liste do maior para o menor.

# %%
#Temos que ver quantas vezes recebi o pagamento daquele filme
# Toda vez que agrupo, agrego (SUM ou whereverrrrr)
db('''
SELECT 
    name, SUM(amount) as receita
FROM
    payment
    INNER JOIN rental USING (customer_id)
    INNER JOIN inventory USING (inventory_id)
    INNER JOIN film_category USING (film_id)
    INNER JOIN category USING (category_id)
GROUP BY
    category_id
ORDER BY
    receita DESC

''')
# Out:
# Executando query:
# ('Sports', Decimal('138295.47'))
# ('Animation', Decimal('137116.48'))
# ('Action', Decimal('130684.74'))
# ('Family', Decimal('129048.71'))
# ('Sci-Fi', Decimal('127768.37'))
# ('Drama', Decimal('122052.28'))
# ('Documentary', Decimal('122046.18'))
# ('Foreign', Decimal('120780.50'))
# ('Games', Decimal('114451.03'))
# ('New', Decimal('110441.67'))
# ('Comedy', Decimal('110384.27'))
# ('Children', Decimal('109727.41'))
# ('Classics', Decimal('108921.82'))
# ('Horror', Decimal('98382.66'))
# ('Travel', Decimal('97279.09'))
# ('Music', Decimal('95838.49'))

# %% [markdown]
# Liste os filmes e o numero de vezes em que foram alugados

# %%
#Depois de fazer essa filtragem vou ter uma tabela com os filmes repetidos e o seu id. Aí tenho que agrupar pelo mesmo nome
# e depois que agrupo, agrego com o COUNT.

db('''
SELECT 
    title, COUNT(rental_id) as vezes_alugados
FROM
    film
    INNER JOIN inventory USING (film_id)
    INNER JOIN rental USING (inventory_id)
GROUP BY
    film_id
ORDER BY
    vezes_alugados DESC
''')
# Out:
# Executando query:
# ('BUCKET BROTHERHOOD', 34)
# ('ROCKETEER MOTHER', 33)
# ('FORWARD TEMPLE', 32)
# ('GRIT CLOCKWORK', 32)
# ('JUGGLER HARDLY', 32)
# ('RIDGEMONT SUBMARINE', 32)
# ('SCALAWAG DUCK', 32)
# ('APACHE DIVINE', 31)
# ('GOODFELLAS SALUTE', 31)
# ('HOBBIT ALIEN', 31)
# ('NETWORK PEAK', 31)
# ('ROBBERS JOON', 31)
# ('RUSH GOODFELLAS', 31)
# ('TIMBERLAND SKY', 31)
# ('WIFE TURN', 31)
# ('ZORRO ARK', 31)
# ('BUTTERFLY CHOCOLAT', 30)
# ('CAT CONEHEADS', 30)
# ('DOGMA FAMILY', 30)
# ('ENGLISH BULWORTH', 30)
# ('FROST HEAD', 30)
# ('GRAFFITI LOVE', 30)
# ('HARRY IDAHO', 30)
# ('IDOLS SNATCHERS', 30)
# ('MARRIED GO', 30)
# ('MASSACRE USUAL', 30)
# ('BARBARELLA STREETCAR', 25)
# ('CLASH FREDDY', 25)
# ('CLUELESS BUCKET', 25)
# ('CONEHEADS SMOOCHY', 25)
# ('DOUBLE WRATH', 25)
# ('DOWNHILL ENOUGH', 25)
# ('DYNAMITE TARZAN', 25)
# ('EFFECT GLADIATOR', 25)
# ('ESCAPE METROPOLIS', 25)
# ('FEUD FROGMEN', 25)
# ('FISH OPUS', 25)
# ('GUN BONNIE', 25)
# ('HILLS NEIGHBORS', 25)
# ('MADNESS ATTACKS', 25)
# ('MALLRATS UNITED', 25)
# ('METAL ARMAGEDDON', 25)
# ('NIGHTMARE CHILL', 25)
# ('OSCAR GOLD', 25)
# ('SAMURAI LION', 25)
# ('SHEPHERD MIDSUMMER', 25)
# ('SHOW LORD', 25)
# ('STREETCAR INTENTIONS', 25)
# ('SUN CONFESSIONS', 25)
# ('TELEMARK HEARTBREAKERS', 25)
# ('TOMORROW HUSTLER', 25)
# ('TRADING PINOCCHIO', 25)
# ('WORKING MICROCOSMOS', 25)
# ('ALAMO VIDEOTAPE', 24)
# ('ARACHNOPHOBIA ROLLERCOASTER', 24)
# ('ATLANTIS CAUSE', 24)
# ('ATTRACTION NEWTON', 24)
# ('BOUND CHEAPER', 24)
# ('CAPER MOTIONS', 24)
# ('CELEBRITY HORN', 24)
# ('CENTER DINOSAUR', 24)
# ('COLOR PHILADELPHIA', 24)
# ('DRIFTER COMMANDMENTS', 24)
# ('FARGO GANDHI', 24)
# ('GOLDFINGER SENSIBILITY', 24)
# ('GUNFIGHT MOON', 24)
# ('HORN WORKING', 24)
# ('HURRICANE AFFAIR', 24)
# ('ICE CROSSING', 24)
# ('JASON TRAP', 24)
# ('JUMPING WRATH', 24)
# ('KNOCK WARLOCK', 24)
# ('LOLA AGENT', 24)
# ('MAIDEN HOME', 24)
# ('MOCKINGBIRD HOLLYWOOD', 24)
# ('ORANGE GRAPES', 24)
# ('OZ LIAISONS', 24)
# ('PACIFIC AMISTAD', 24)
# ('ROMAN PUNK', 24)
# ('SEATTLE EXPECATIONS', 24)
# ('SHOOTIST SUPERFLY', 24)
# ('SLEEPING SUSPECTS', 24)
# ('SLUMS DUCK', 24)
# ('STRANGELOVE DESIRE', 24)
# ('SUNRISE LEAGUE', 24)
# ('WEDDING APOLLO', 24)
# ('ACADEMY DINOSAUR', 23)
# ('AFFAIR PREJUDICE', 23)
# ('ALADDIN CALENDAR', 23)
# ('BALLOON HOMEWARD', 23)
# ('CANDLES GRAPES', 23)
# ('CARRIE BUNCH', 23)
# ('CROOKED FROGMEN', 23)
# ('CUPBOARD SINNERS', 23)
# ('EARTH VISION', 23)
# ('EASY GLADIATOR', 23)
# ('FLAMINGOS CONNECTICUT', 23)
# ('FOOL MOCKINGBIRD', 23)
# ('FREDDY STORM', 23)
# ('GENTLEMEN STAGE', 23)
# ('HEAVYWEIGHTS BEAST', 23)
# ('HOUSE DYNAMITE', 23)
# ('KARATE MOON', 23)
# ('KWAI HOMEWARD', 23)
# ('MURDER ANTITRUST', 23)
# ('NAME DETECTIVE', 23)
# ('OTHERS SOUP', 23)
# ('OUTBREAK DIVINE', 23)
# ('PATTON INTERVIEW', 23)
# ('PHILADELPHIA WIFE', 23)
# ('SALUTE APOLLO', 23)
# ('SCORPION APOLLO', 23)
# ('SNOWMAN ROLLERCOASTER', 23)
# ('STEEL SANTA', 23)
# ('STRICTLY SCARFACE', 23)
# ('TITANIC BOONDOCK', 23)
# ('TROUBLE DATE', 23)
# ('TRUMAN CRAZY', 23)
# ('WASH HEAVENLY', 23)
# ('WIND PHANTOM', 23)
# ('WOMEN DORADO', 23)
# ('YENTL IDAHO', 23)
# ('ALIEN CENTER', 22)
# ('ALTER VICTORY', 22)
# ('AMERICAN CIRCUS', 22)
# ('ANGELS LIFE', 22)
# ('ANNIE IDENTITY', 22)
# ('BANGER PINOCCHIO', 22)
# ('BEAR GRACELAND', 22)
# ('BEAUTY GREASE', 22)
# ('BLADE POLISH', 22)
# ('BORROWERS BEDAZZLED', 22)
# ('CHICKEN HELLFIGHTERS', 22)
# ('CHILL LUCK', 22)
# ('CONGENIALITY QUEST', 22)
# ('DREAM PICKUP', 22)
# ('EAGLES PANKY', 22)
# ('FALCON VOLUME', 22)
# ('FIGHT JAWBREAKER', 22)
# ('FLATLINERS KILLER', 22)
# ('GRAPES FURY', 22)
# ('HAUNTING PIANIST', 22)
# ('HEAD STRANGER', 22)
# ('HIGH ENCINO', 22)
# ('HOMICIDE PEACH', 22)
# ('HUSTLER PARTY', 22)
# ('KISS GLORY', 22)
# ('LIAISONS SWEET', 22)
# ('MALTESE HOPE', 22)
# ('MIDSUMMER GROUNDHOG', 22)
# ('PACKER MADIGAN', 22)
# ('QUEEN LUKE', 22)
# ('SEA VIRGIN', 22)
# ('SHAKESPEARE SADDLE', 22)
# ('SINNERS ATLANTIS', 22)
# ('SNATCH SLIPPER', 22)
# ('SOUTH WAIT', 22)
# ('TOURIST PELICAN', 22)
# ('VOLCANO TEXAS', 22)
# ('WHISPERER GIANT', 22)
# ('WONDERLAND CHRISTMAS', 22)
# ('AGENT TRUMAN', 21)
# ('AMADEUS HOLY', 21)
# ('AMISTAD MIDSUMMER', 21)
# ('ANACONDA CONFESSIONS', 21)
# ('ARIZONA BANG', 21)
# ('ARMAGEDDON LOST', 21)
# ('BADMAN DAWN', 21)
# ('BASIC EASY', 21)
# ('BERETS AGENT', 21)
# ('BEVERLY OUTLAW', 21)
# ('BLUES INSTINCT', 21)
# ('BROOKLYN DESERT', 21)
# ('CALENDAR GUNFIGHT', 21)
# ('CAUSE DATE', 21)
# ('CHAINSAW UPTOWN', 21)
# ('CHARIOTS CONSPIRACY', 21)
# ('CHRISTMAS MOONSHINE', 21)
# ('COAST RAINBOW', 21)
# ('CROSSROADS CASUALTIES', 21)
# ('DECEIVER BETRAYED', 21)
# ('DIVIDE MONSTER', 21)
# ('DOOM DANCING', 21)
# ('DRACULA CRYSTAL', 21)
# ('DRIVING POLISH', 21)
# ('EGG IGBY', 21)
# ('EMPIRE MALKOVICH', 21)
# ('EXCITEMENT EVE', 21)
# ('LADYBUGS ARMAGEDDON', 6)
# ('OKLAHOMA JUMANJI', 6)
# ('PHANTOM GLORY', 6)
# ('RUSHMORE MERMAID', 6)
# ('SCHOOL JACKET', 6)
# ('SIMON NORTH', 6)
# ('SLING LUKE', 6)
# ('TEQUILA PAST', 6)
# ('TERMINATOR CLUB', 6)
# ('TEXAS WATCH', 6)
# ('WARLOCK WEREWOLF', 6)
# ('WATERSHIP FRONTIER', 6)
# ('WILD APOLLO', 6)
# ('YOUTH KICK', 6)
# ('BRAVEHEART HUMAN', 5)
# ('BUNCH MINDS', 5)
# ('CONSPIRACY SPIRIT', 5)
# ('FEVER EMPIRE', 5)
# ('FREEDOM CLEOPATRA', 5)
# ('FULL FLATLINERS', 5)
# ('GLORY TRACY', 5)
# ('HUNTER ALTER', 5)
# ('INFORMER DOUBLE', 5)
# ('MANNEQUIN WORST', 5)
# ('MUSSOLINI SPOILERS', 5)
# ('PRIVATE DROP', 5)
# ('SEVEN SWARM', 5)
# ('TRAFFIC HOBBIT', 5)
# ('HARDLY ROBBERS', 4)
# ('MIXED DOORS', 4)
# ('TRAIN BUNCH', 4)

# %% [markdown]
# Liste os filmes e o numero de vezes em que foram alugados apenas para filmes que foram alugados mais do que a média de numero de alugueis por filme.

# %%
db('''
SELECT 
    COUNT(film_id) INTO @cnt_film
FROM
    film
''')

db('''
SELECT
    COUNT(rental_id) INTO @cnt_rental
FROM
    rental
''')

db('''
SELECT 
    @cnt_rental/@cnt_film INTO @avg_rental_per_film
''')

db('''
SELECT
    @avg_rental_per_film

''')
# Out:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# (Decimal('16.044000000'),)

# %%
#Depois de fazer essa filtragem vou ter uma tabela com os filmes repetidos e o seu id. Aí tenho que agrupar pelo mesmo nome
# e depois que agrupo, agrego com o COUNT.

db('''
SELECT 
    title, COUNT(rental_id) as vezes_alugados
FROM
    film
    INNER JOIN inventory USING (film_id)
    INNER JOIN rental USING (inventory_id)
GROUP BY
    film_id
HAVING
    vezes_alugados > @avg_rental_per_film
ORDER BY
    vezes_alugados ASC
''')
# Out:
# Executando query:
# ('BEACH HEARTBREAKERS', 17)
# ('BIKINI BORROWERS', 17)
# ('BREAKFAST GOLDFINGER', 17)
# ('COMFORTS RUSH', 17)
# ('CONFUSED CANDLES', 17)
# ('CONVERSATION DOWNHILL', 17)
# ('DYING MAKER', 17)
# ('EGYPT TENENBAUMS', 17)
# ('FACTORY DRAGON', 17)
# ('FERRIS MOTHER', 17)
# ('FLINTSTONES HAPPINESS', 17)
# ('FREAKY POCUS', 17)
# ('FRENCH HOLIDAY', 17)
# ('GANDHI KWAI', 17)
# ('GREEK EVERYONE', 17)
# ('HANOVER GALAXY', 17)
# ('HOLOCAUST HIGHBALL', 17)
# ('IDAHO LOVE', 17)
# ('INTENTIONS EMPIRE', 17)
# ('JEKYLL FROGMEN', 17)
# ('JERICHO MULAN', 17)
# ('JOON NORTHWEST', 17)
# ('LADY STAGE', 17)
# ('LAWLESS VISION', 17)
# ('AFFAIR PREJUDICE', 23)
# ('ALADDIN CALENDAR', 23)
# ('BALLOON HOMEWARD', 23)
# ('CANDLES GRAPES', 23)
# ('CARRIE BUNCH', 23)
# ('CROOKED FROGMEN', 23)
# ('CUPBOARD SINNERS', 23)
# ('EARTH VISION', 23)
# ('EASY GLADIATOR', 23)
# ('FLAMINGOS CONNECTICUT', 23)
# ('FOOL MOCKINGBIRD', 23)
# ('FREDDY STORM', 23)
# ('GENTLEMEN STAGE', 23)
# ('HEAVYWEIGHTS BEAST', 23)
# ('HOUSE DYNAMITE', 23)
# ('KARATE MOON', 23)
# ('KWAI HOMEWARD', 23)
# ('MURDER ANTITRUST', 23)
# ('NAME DETECTIVE', 23)
# ('OTHERS SOUP', 23)
# ('OUTBREAK DIVINE', 23)
# ('PATTON INTERVIEW', 23)
# ('PHILADELPHIA WIFE', 23)
# ('SALUTE APOLLO', 23)
# ('SCORPION APOLLO', 23)
# ('SNOWMAN ROLLERCOASTER', 23)
# ('STEEL SANTA', 23)
# ('STRICTLY SCARFACE', 23)
# ('TITANIC BOONDOCK', 23)
# ('TROUBLE DATE', 23)
# ('TRUMAN CRAZY', 23)
# ('WASH HEAVENLY', 23)
# ('WIND PHANTOM', 23)
# ('WOMEN DORADO', 23)
# ('YENTL IDAHO', 23)
# ('ALAMO VIDEOTAPE', 24)
# ('ARACHNOPHOBIA ROLLERCOASTER', 24)
# ('ATLANTIS CAUSE', 24)
# ('ATTRACTION NEWTON', 24)
# ('BOUND CHEAPER', 24)
# ('CAPER MOTIONS', 24)
# ('CELEBRITY HORN', 24)
# ('CENTER DINOSAUR', 24)
# ('COLOR PHILADELPHIA', 24)
# ('DRIFTER COMMANDMENTS', 24)
# ('FARGO GANDHI', 24)
# ('GOLDFINGER SENSIBILITY', 24)
# ('GUNFIGHT MOON', 24)
# ('HORN WORKING', 24)
# ('HURRICANE AFFAIR', 24)
# ('ICE CROSSING', 24)
# ('JASON TRAP', 24)
# ('JUMPING WRATH', 24)
# ('KNOCK WARLOCK', 24)
# ('LOLA AGENT', 24)
# ('MAIDEN HOME', 24)
# ('MOCKINGBIRD HOLLYWOOD', 24)
# ('ORANGE GRAPES', 24)
# ('OZ LIAISONS', 24)
# ('PACIFIC AMISTAD', 24)
# ('ROMAN PUNK', 24)
# ('SEATTLE EXPECATIONS', 24)
# ('SHOOTIST SUPERFLY', 24)
# ('SLEEPING SUSPECTS', 24)
# ('SLUMS DUCK', 24)
# ('STRANGELOVE DESIRE', 24)
# ('SUNRISE LEAGUE', 24)
# ('WEDDING APOLLO', 24)
# ('BARBARELLA STREETCAR', 25)
# ('CLASH FREDDY', 25)
# ('CLUELESS BUCKET', 25)
# ('CONEHEADS SMOOCHY', 25)
# ('DOUBLE WRATH', 25)
# ('DOWNHILL ENOUGH', 25)
# ('DYNAMITE TARZAN', 25)
# ('EFFECT GLADIATOR', 25)
# ('ESCAPE METROPOLIS', 25)
# ('FEUD FROGMEN', 25)
# ('FISH OPUS', 25)
# ('GUN BONNIE', 25)
# ('GLEAMING JAWBREAKER', 29)
# ('GREATEST NORTH', 29)
# ('MOON BUNCH', 29)
# ('STORM HAPPINESS', 29)
# ('SWEETHEARTS SUSPECTS', 29)
# ('TALENTED HOMICIDE', 29)
# ('TITANS JERK', 29)
# ('VIDEOTAPE ARSENIC', 29)
# ('VIRGINIAN PLUTO', 29)
# ('BUTTERFLY CHOCOLAT', 30)
# ('CAT CONEHEADS', 30)
# ('DOGMA FAMILY', 30)
# ('ENGLISH BULWORTH', 30)
# ('FROST HEAD', 30)
# ('GRAFFITI LOVE', 30)
# ('HARRY IDAHO', 30)
# ('IDOLS SNATCHERS', 30)
# ('MARRIED GO', 30)
# ('MASSACRE USUAL', 30)
# ('MUSCLE BRIGHT', 30)
# ('PULP BEVERLY', 30)
# ('RUGRATS SHAKESPEARE', 30)
# ('SHOCK CABIN', 30)
# ('SUSPECTS QUILLS', 30)
# ('WITCHES PANIC', 30)
# ('APACHE DIVINE', 31)
# ('GOODFELLAS SALUTE', 31)
# ('HOBBIT ALIEN', 31)
# ('NETWORK PEAK', 31)
# ('ROBBERS JOON', 31)
# ('RUSH GOODFELLAS', 31)
# ('TIMBERLAND SKY', 31)
# ('WIFE TURN', 31)
# ('ZORRO ARK', 31)
# ('FORWARD TEMPLE', 32)
# ('GRIT CLOCKWORK', 32)
# ('JUGGLER HARDLY', 32)
# ('RIDGEMONT SUBMARINE', 32)
# ('SCALAWAG DUCK', 32)
# ('ROCKETEER MOTHER', 33)
# ('BUCKET BROTHERHOOD', 34)

# %% [markdown]
# ## Views
#
# Uma *view* é uma tabela virtual, construida a partir de um comando `SELECT`. Por exemplo: execute o código a seguir.

# %%
#Quantas vezes foram alugados mesmo para filmes que nunca foram alugados: com cnt igual a 0
#Todos os filmes serão presentes mesmo que não haja [cópia física em lugar nenhum = inventory]
# e mesmo que nunca tenha sido alugado na vida
#pode ter quantos nulos for, ele conta como 0
db('''
DROP VIEW IF EXISTS movie_count;
''')

db('''
CREATE VIEW movie_count AS
    SELECT 
        title, COUNT(rental_id) as cnt
    FROM
        film
        LEFT OUTER JOIN inventory USING (film_id)
        LEFT OUTER JOIN rental USING (inventory_id)
    GROUP BY
        film_id
    ORDER BY
        cnt ASC;
''')
# Out:
# Executando query:
# Executando query:

# %% [markdown]
# Agora temos uma *view* chamada `movie_count`. Vamos verificar que ela funcionou, listando as 30 primeiras linhas:

# %%
db('''
SELECT 
    *
FROM
    movie_count 
LIMIT 
    30
''')
# Out:
# Executando query:
# ('ALICE FANTASIA', 0)
# ('APOLLO TEEN', 0)
# ('ARGONAUTS TOWN', 0)
# ('ARK RIDGEMONT', 0)
# ('ARSENIC INDEPENDENCE', 0)
# ('BOONDOCK BALLROOM', 0)
# ('BUTCH PANTHER', 0)
# ('CATCH AMISTAD', 0)
# ('CHINATOWN GLADIATOR', 0)
# ('CHOCOLATE DUCK', 0)
# ('COMMANDMENTS EXPRESS', 0)
# ('CROSSING DIVORCE', 0)
# ('CROWDS TELEMARK', 0)
# ('CRYSTAL BREAKING', 0)
# ('STONED PUNK', 0)
# ('DELIVERANCE MULHOLLAND', 0)
# ('FIREHOUSE VIETNAM', 0)
# ('FLOATS GARDEN', 0)
# ('FRANKENSTEIN STRANGER', 0)
# ('GLADIATOR WESTWARD', 0)
# ('GUMP DATE', 0)
# ('HATE HANDICAP', 0)
# ('HOCUS FRIDA', 0)
# ('KENTUCKIAN GIANT', 0)
# ('KILL BROTHERHOOD', 0)
# ('MUPPET MILE', 0)
# ('ORDER BETRAYED', 0)
# ('PEARL DESTINY', 0)
# ('PERDITION FARGO', 0)
# ('PSYCHO SHRUNK', 0)

# %%
db('''
SELECT 
    * 
FROM 
    movie_count 
ORDER BY
    cnt DESC
LIMIT 30
''')
# Out:
# Executando query:
# ('BUCKET BROTHERHOOD', 34)
# ('ROCKETEER MOTHER', 33)
# ('JUGGLER HARDLY', 32)
# ('GRIT CLOCKWORK', 32)
# ('FORWARD TEMPLE', 32)
# ('SCALAWAG DUCK', 32)
# ('RIDGEMONT SUBMARINE', 32)
# ('ZORRO ARK', 31)
# ('WIFE TURN', 31)
# ('TIMBERLAND SKY', 31)
# ('RUSH GOODFELLAS', 31)
# ('ROBBERS JOON', 31)
# ('NETWORK PEAK', 31)
# ('HOBBIT ALIEN', 31)
# ('GOODFELLAS SALUTE', 31)
# ('APACHE DIVINE', 31)
# ('WITCHES PANIC', 30)
# ('SUSPECTS QUILLS', 30)
# ('SHOCK CABIN', 30)
# ('RUGRATS SHAKESPEARE', 30)
# ('PULP BEVERLY', 30)
# ('MUSCLE BRIGHT', 30)
# ('MASSACRE USUAL', 30)
# ('MARRIED GO', 30)
# ('IDOLS SNATCHERS', 30)
# ('HARRY IDAHO', 30)
# ('GRAFFITI LOVE', 30)
# ('FROST HEAD', 30)
# ('ENGLISH BULWORTH', 30)
# ('DOGMA FAMILY', 30)

# %% [markdown]
# Agora suponha que alteramos a tabela `film`, mudando o nome do filme "DAZED PUNK" para "STONED PUNK".
#
# **Atividade**: Do it.

# %%
db('''
UPDATE film SET title="STONED PUNK" WHERE title="DAZED PUNK"
''')
# Out:
# Executando query:

# %% [markdown]
# Verifique agora a nossa *view*:

# %%
db('''
SELECT
    *
FROM
    movie_count
LIMIT
    30
''')
# Out:
# Executando query:
# ('ALICE FANTASIA', 0)
# ('APOLLO TEEN', 0)
# ('ARGONAUTS TOWN', 0)
# ('ARK RIDGEMONT', 0)
# ('ARSENIC INDEPENDENCE', 0)
# ('BOONDOCK BALLROOM', 0)
# ('BUTCH PANTHER', 0)
# ('CATCH AMISTAD', 0)
# ('CHINATOWN GLADIATOR', 0)
# ('CHOCOLATE DUCK', 0)
# ('COMMANDMENTS EXPRESS', 0)
# ('CROSSING DIVORCE', 0)
# ('CROWDS TELEMARK', 0)
# ('CRYSTAL BREAKING', 0)
# ('STONED PUNK', 0)
# ('DELIVERANCE MULHOLLAND', 0)
# ('FIREHOUSE VIETNAM', 0)
# ('FLOATS GARDEN', 0)
# ('FRANKENSTEIN STRANGER', 0)
# ('GLADIATOR WESTWARD', 0)
# ('GUMP DATE', 0)
# ('HATE HANDICAP', 0)
# ('HOCUS FRIDA', 0)
# ('KENTUCKIAN GIANT', 0)
# ('KILL BROTHERHOOD', 0)
# ('MUPPET MILE', 0)
# ('ORDER BETRAYED', 0)
# ('PEARL DESTINY', 0)
# ('PERDITION FARGO', 0)
# ('PSYCHO SHRUNK', 0)

# %% [markdown]
# Como você pode ver, as views são tabelas virtuais que são automaticamente atualizadas quando as tabelas originais são modificadas.

# %%
connection.rollback()

# %%
db('''
SELECT
    *
FROM
    movie_count
LIMIT
    30
''')
# Out:
# Executando query:
# ('ALICE FANTASIA', 0)
# ('APOLLO TEEN', 0)
# ('ARGONAUTS TOWN', 0)
# ('ARK RIDGEMONT', 0)
# ('ARSENIC INDEPENDENCE', 0)
# ('BOONDOCK BALLROOM', 0)
# ('BUTCH PANTHER', 0)
# ('CATCH AMISTAD', 0)
# ('CHINATOWN GLADIATOR', 0)
# ('CHOCOLATE DUCK', 0)
# ('COMMANDMENTS EXPRESS', 0)
# ('CROSSING DIVORCE', 0)
# ('CROWDS TELEMARK', 0)
# ('CRYSTAL BREAKING', 0)
# ('STONED PUNK', 0)
# ('DELIVERANCE MULHOLLAND', 0)
# ('FIREHOUSE VIETNAM', 0)
# ('FLOATS GARDEN', 0)
# ('FRANKENSTEIN STRANGER', 0)
# ('GLADIATOR WESTWARD', 0)
# ('GUMP DATE', 0)
# ('HATE HANDICAP', 0)
# ('HOCUS FRIDA', 0)
# ('KENTUCKIAN GIANT', 0)
# ('KILL BROTHERHOOD', 0)
# ('MUPPET MILE', 0)
# ('ORDER BETRAYED', 0)
# ('PEARL DESTINY', 0)
# ('PERDITION FARGO', 0)
# ('PSYCHO SHRUNK', 0)

# %%
db('''
UPDATE film SET title="DAZED PUNK" WHERE title="STONED PUNK"
''')
# Out:
# Executando query:

# %%
db('''
SELECT
    *
FROM
    movie_count
LIMIT
    30
''')
# Out:
# Executando query:
# ('ALICE FANTASIA', 0)
# ('APOLLO TEEN', 0)
# ('ARGONAUTS TOWN', 0)
# ('ARK RIDGEMONT', 0)
# ('ARSENIC INDEPENDENCE', 0)
# ('BOONDOCK BALLROOM', 0)
# ('BUTCH PANTHER', 0)
# ('CATCH AMISTAD', 0)
# ('CHINATOWN GLADIATOR', 0)
# ('CHOCOLATE DUCK', 0)
# ('COMMANDMENTS EXPRESS', 0)
# ('CROSSING DIVORCE', 0)
# ('CROWDS TELEMARK', 0)
# ('CRYSTAL BREAKING', 0)
# ('DAZED PUNK', 0)
# ('DELIVERANCE MULHOLLAND', 0)
# ('FIREHOUSE VIETNAM', 0)
# ('FLOATS GARDEN', 0)
# ('FRANKENSTEIN STRANGER', 0)
# ('GLADIATOR WESTWARD', 0)
# ('GUMP DATE', 0)
# ('HATE HANDICAP', 0)
# ('HOCUS FRIDA', 0)
# ('KENTUCKIAN GIANT', 0)
# ('KILL BROTHERHOOD', 0)
# ('MUPPET MILE', 0)
# ('ORDER BETRAYED', 0)
# ('PEARL DESTINY', 0)
# ('PERDITION FARGO', 0)
# ('PSYCHO SHRUNK', 0)

# %% [markdown]
# ### Vamos praticar

# %% [markdown]
# Verifique quantas vezes o filme "COWBOY DOOM" foi alugado usando a view `movie_count`

# %%
db('''
SELECT
    title, cnt
FROM 
    movie_count
WHERE
    title = 'COWBOY DOOM'
''')
# Out:
# Executando query:
# ('COWBOY DOOM', 7)

# %% [markdown]
# Registre um aluguel do filme "COWBOY DOOM", feito pelo funcionario "Jon Stephens" na loja id=1 para o cliente "JESSIE BANKS", na data '2019-01-01', com data de retorno '2019-01-08'

# %%
db('''
SELECT 
    film_id INTO @film_id  
FROM
    film
WHERE
    title = 'COWBOY DOOM'
''')
# Out:
# Executando query:

# %%
db('''
SELECT
    *
FROM
    film
    INNER JOIN inventory USING (film_id)
WHERE
    title = 'COWBOY DOOM'
''')
# Out:
# Executando query:
# (185, 'COWBOY DOOM', 'A Astounding Drama of a Boy And a Lumberjack who must Fight a Butler in A Baloon', 2006, 1, None, 3, Decimal('2.99'), 146, Decimal('10.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 845, 1, datetime.datetime(2006, 2, 15, 5, 9, 17))
# (185, 'COWBOY DOOM', 'A Astounding Drama of a Boy And a Lumberjack who must Fight a Butler in A Baloon', 2006, 1, None, 3, Decimal('2.99'), 146, Decimal('10.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 846, 1, datetime.datetime(2006, 2, 15, 5, 9, 17))

# %%
db('''
SELECT 
    staff_id INTO @staff_id  
FROM
    staff
WHERE
    first_name = 'Jon'
    AND last_name = 'Stephens'
''')
# Out:
# Executando query:

# %%
db('''
SELECT 
    customer_id INTO @customer_id  
FROM
    customer
WHERE
    first_name = 'JESSIE'
    AND last_name = 'BANKS'
''')
# Out:
# Executando query:

# %%
db('''
SELECT
    MIN(inventory_id)
FROM
    film
    INNER JOIN inventory USING (film_id)
WHERE
    title = 'COWBOY DOOM'
''')
# Out:
# Executando query:
# (845,)

# %%
db('''
INSERT INTO rental (
    rental_date, 
    inventory_id, 
    customer_id, 
    return_date, 
    staff_id
)
VALUES 
(
    "2019-01-01",
    @inventory_id,
    @customer_id,
    "2019-01-08",
    @staff_id
)''')
# Out:
# Executando query:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     559                 raw_as_string=raw_as_string,
# --> 560                 query_attrs=self._query_attrs,
#     561             )
#
# MySQLInterfaceError: Column 'inventory_id' cannot be null
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-21-66ce33648cc8> in <module>
#      14     "2019-01-08",
#      15     @staff_id
# ---> 16 )''')
#
# <ipython-input-1-f8cf815155f2> in run_db_query(connection, query, args)
#       8         with connection.cursor() as cursor:
#       9             print('Executando query:')
# ---> 10             cursor.execute(query, args)
#      11             for result in cursor:
#      12                 print(result)
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     278                 raw=self._raw,
#     279                 buffered=self._buffered,
# --> 280                 raw_as_string=self._raw_as_string,
#     281             )
#     282         except MySQLInterfaceError as err:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     563             raise get_mysql_exception(
#     564                 err.errno, msg=err.msg, sqlstate=err.sqlstate
# --> 565             ) from err
#     566         except AttributeError as err:
#     567             addr = (
#
# IntegrityError: 1048 (23000): Column 'inventory_id' cannot be null

# %% [markdown]
# Verifique usando a view que a contagem de alugueis do filme subiu.

# %%
db('''
SELECT
    title, cnt
FROM 
    movie_count
WHERE
    title = 'COWBOY DOOM'
''')
# Out:
# Executando query:
# ('COWBOY DOOM', 7)

# %% [markdown]
# Faça o *rollback* desta alteração, para não modificar a nossa querida base de dados *sakila*.

# %%
connection.rollback()

# %%
db('''
SELECT
    title, cnt
FROM 
    movie_count
WHERE
    title = 'COWBOY DOOM'
''')
# Out:
# Executando query:
# ('COWBOY DOOM', 7)

# %% [markdown]
# ## Tabelas temporárias

# %% [markdown]
# Tabelas temporárias podem ser criadas para ajudar nas tarefas de manipulação de dados. Essas tabelas existem apenas pela duração da sessão. Para criar uma tabela temporária, basta adicionar a palavra-chave `TEMPORARY` no momento da criação.
#
# É comum criar tabelas temporárias à partir do resultado de comandos `SELECT`. Por exemplo, a seguinte query permite montar uma tabela temporária com os filmes que duram mais que 3 horas:

# %%
db('''
DROP TABLE IF EXISTS long_film

''')

db('''
CREATE TEMPORARY TABLE long_film 
    SELECT
        *
    FROM
        film
    WHERE
        film.length > 180;
''')
# Out:
# Executando query:
# Executando query:

# %% [markdown]
# Podemos verificar que a tabela `long_film` agora existe:

# %%
db('DESCRIBE long_film')
# Out:
# Executando query:
# ('film_id', 'smallint unsigned', 'NO', '', '0', 'NULL')
# ('title', 'varchar(128)', 'NO', '', None, 'NULL')
# ('description', 'text', 'YES', '', None, 'NULL')
# ('release_year', 'year', 'YES', '', None, 'NULL')
# ('language_id', 'tinyint unsigned', 'NO', '', None, 'NULL')
# ('original_language_id', 'tinyint unsigned', 'YES', '', None, 'NULL')
# ('rental_duration', 'tinyint unsigned', 'NO', '', '3', 'NULL')
# ('rental_rate', 'decimal(4,2)', 'NO', '', '4.99', 'NULL')
# ('length', 'smallint unsigned', 'YES', '', None, 'NULL')
# ('replacement_cost', 'decimal(5,2)', 'NO', '', '19.99', 'NULL')
# ('rating', "enum('G','PG','PG-13','R','NC-17')", 'YES', '', 'G', 'NULL')
# ('special_features', "set('Trailers','Commentaries','Deleted Scenes','Behind the Scenes')", 'YES', '', None, 'NULL')
# ('last_update', 'timestamp', 'NO', '', 'CURRENT_TIMESTAMP', 'on update CURRENT_TIMESTAMP')

# %% [markdown]
# Muito embora ela não apareça na lista de tabelas: isso é um bug do MySQL. (https://dev.mysql.com/worklog/task/?id=648)

# %%
db('SHOW TABLES')
# Out:
# Executando query:
# ('actor',)
# ('actor_info',)
# ('address',)
# ('category',)
# ('city',)
# ('country',)
# ('customer',)
# ('customer_list',)
# ('film',)
# ('film_actor',)
# ('film_category',)
# ('film_list',)
# ('film_text',)
# ('inventory',)
# ('language',)
# ('movie_count',)
# ('nicer_but_slower_film_list',)
# ('payment',)
# ('rental',)
# ('sales_by_film_category',)
# ('sales_by_store',)
# ('staff',)
# ('staff_list',)
# ('store',)

# %% [markdown]
# Vamos listar o conteudo desta tabela:

# %%
db('SELECT title FROM long_film')
# Out:
# Executando query:
# ('ANALYZE HOOSIERS',)
# ('BAKED CLEOPATRA',)
# ('CATCH AMISTAD',)
# ('CHICAGO NORTH',)
# ('CONSPIRACY SPIRIT',)
# ('CONTROL ANTHEM',)
# ('CRYSTAL BREAKING',)
# ('DARN FORRESTER',)
# ('FRONTIER CABIN',)
# ('GANGS PRIDE',)
# ('HAUNTING PIANIST',)
# ('HOME PITY',)
# ('HOTEL HAPPINESS',)
# ('INTRIGUE WORST',)
# ('JACKET FRISCO',)
# ('KING EVOLUTION',)
# ('LAWLESS VISION',)
# ('LOVE SUICIDES',)
# ('MONSOON CAUSE',)
# ('MOONWALKER FOOL',)
# ('MUSCLE BRIGHT',)
# ('POND SEATTLE',)
# ('RECORDS ZORRO',)
# ('REDS POCUS',)
# ('RUNAWAY TENENBAUMS',)
# ('SATURN NAME',)
# ('SCALAWAG DUCK',)
# ('SEARCHERS WAIT',)
# ('SMOOCHY CONTROL',)
# ('SOLDIERS EVOLUTION',)
# ('SONS INTERVIEW',)
# ('SORORITY QUEEN',)
# ('STAR OPERATION',)
# ('SWEET BROTHERHOOD',)
# ('THEORY MERMAID',)
# ('WIFE TURN',)
# ('WILD APOLLO',)
# ('WORST BANGER',)
# ('YOUNG LANGUAGE',)

# %% [markdown]
# Vamos apagar a tabela `long_film`:

# %%
db('DROP TABLE long_film')
# Out:
# Executando query:

# %% [markdown]
# ### Vamos praticar

# %% [markdown]
# - Crie uma tabela temporária `max_duration` que contém a duração máxima de filme para cada categoria

# %%
db('''
DROP TABLE IF EXISTS max_duration

''')

db('''
CREATE TEMPORARY TABLE max_duration 
    SELECT
        category_id, name, MAX(length) as duracaoMax
    FROM
        film
        INNER JOIN film_category USING (film_id)
        INNER JOIN category USING (category_id)
    GROUP BY
        category_id
    ORDER BY
        duracaoMax DESC
    
''')
# Out:
# Executando query:
# Executando query:

# %% [markdown]
#  - Verifique a tabela.

# %%
db('''
SELECT
    *
FROM 
    max_duration
''')
# Out:
# Executando query:
# (1, 'Action', 185)
# (2, 'Animation', 185)
# (5, 'Comedy', 185)
# (10, 'Games', 185)
# (12, 'Music', 185)
# (14, 'Sci-Fi', 185)
# (16, 'Travel', 185)
# (4, 'Classics', 184)
# (8, 'Family', 184)
# (9, 'Foreign', 184)
# (15, 'Sports', 184)
# (6, 'Documentary', 183)
# (13, 'New', 183)
# (7, 'Drama', 181)
# (11, 'Horror', 181)
# (3, 'Children', 178)

# %%
db('DESCRIBE max_duration')
# Out:
# Executando query:
# ('category_id', 'tinyint unsigned', 'NO', '', None, 'NULL')
# ('name', 'varchar(25)', 'NO', '', None, 'NULL')
# ('duracaoMax', 'smallint unsigned', 'YES', '', None, 'NULL')

# %% [markdown]
# - Agora use a tabela temporária para construir uma tabela com as categorias e seus respectivos filmes mais longos:

# %%
db('''
SELECT
    length, duracaoMax, title, name
FROM
    film
    INNER JOIN film_category USING (film_id)
    INNER JOIN max_duration USING (category_id)
WHERE
    length = duracaoMax
''')
# Out:
# Executando query:
# (185, 185, 'DARN FORRESTER', 'Action')
# (185, 185, 'WORST BANGER', 'Action')
# (185, 185, 'GANGS PRIDE', 'Animation')
# (185, 185, 'POND SEATTLE', 'Animation')
# (185, 185, 'CONTROL ANTHEM', 'Comedy')
# (185, 185, 'CHICAGO NORTH', 'Games')
# (185, 185, 'HOME PITY', 'Music')
# (185, 185, 'SOLDIERS EVOLUTION', 'Sci-Fi')
# (185, 185, 'MUSCLE BRIGHT', 'Travel')
# (185, 185, 'SWEET BROTHERHOOD', 'Travel')
# (184, 184, 'CONSPIRACY SPIRIT', 'Classics')
# (184, 184, 'KING EVOLUTION', 'Family')
# (184, 184, 'CRYSTAL BREAKING', 'Foreign')
# (184, 184, 'SORORITY QUEEN', 'Foreign')
# (184, 184, 'SMOOCHY CONTROL', 'Sports')
# (183, 183, 'WIFE TURN', 'Documentary')
# (183, 183, 'YOUNG LANGUAGE', 'Documentary')
# (183, 183, 'FRONTIER CABIN', 'New')
# (181, 181, 'JACKET FRISCO', 'Drama')
# (181, 181, 'ANALYZE HOOSIERS', 'Horror')
# (181, 181, 'LOVE SUICIDES', 'Horror')
# (178, 178, 'FURY MURDER', 'Children')
# (178, 178, 'WRONG BEHAVIOR', 'Children')

# %% [markdown]
# - delete a tabela temporária

# %%
db('DROP TABLE max_duration')
# Out:
# Executando query:

# %% [markdown]
# ### Desafio!

# %% [markdown]
# - Gere uma tabela contendo, para cada ator, a seguinte informação:
#
# | first_name | last_name | filmes por categoria |
# |--|--|--|
# | PENELOPE | GUINESS | Animation: ANACONDA CONFESSIONS; Children: LANGUAGE COWBOY; Classics: COLOR PHILADELPHIA, WESTWARD SEABISCUIT; Comedy: VERTIGO NORTHWEST; Documentary: ACADEMY DINOSAUR; Family: KING EVOLUTION, SPLASH GUMP; Foreign: MULHOLLAND BEAST; Games: BULWORTH COMMANDMENTS, HUMAN GRAFFITI; Horror: ELEPHANT TROJAN, LADY STAGE, RULES HUMAN; Music: WIZARD COLDBLOODED; New: ANGELS LIFE, OKLAHOMA JUMANJI; Sci-Fi: CHEAPER CLYDE; Sports: GLEAMING JAWBREAKER |
# | NICK | WAHLBERG | Action: BULL SHAWSHANK; Animation: FIGHT JAWBREAKER; Children: JERSEY SASSY; Classics: DRACULA CRYSTAL, GILBERT PELICAN; Comedy: MALLRATS UNITED, RUSHMORE MERMAID; Documentary: ADAPTATION HOLES; Drama: WARDROBE PHANTOM; Family: APACHE DIVINE, CHISUM BEHAVIOR, INDIAN LOVE, MAGUIRE APACHE; Foreign: BABY HALL, HAPPINESS UNITED; Games: ROOF CHAMPION; Music: LUCKY FLYING; New: DESTINY SATURDAY, FLASH WARS, JEKYLL FROGMEN, MASK PEACH; Sci-Fi: CHAINSAW UPTOWN, GOODFELLAS SALUTE; Travel: LIAISONS SWEET, SMILE EARRING |
# | etc | etc | etc |
#
# Dica: use `GROUP_CONCAT` para agrupar todas as strings de uma coluna em uma string só, e `CONCAT` para unir strings particulares.

# %%
#Penelope Guiness Animation, ...

db('DROP TABLE IF EXISTS actor_category_films')

db('''
CREATE TEMPORARY TABLE actor_category_films
    SELECT 
        first_name, last_name, CONCAT(name, ":", GROUP_CONCAT(title SEPARATOR ",")) as films

    FROM
        actor
        INNER JOIN film_actor USING (actor_id)
        INNER JOIN film USING (film_id)
        INNER JOIN film_category USING (film_id)
        INNER JOIN category USING (category_id)
    GROUP BY
        actor_id, category_id

''')
# Out:
# Executando query:
# Executando query:

# %%
db('SELECT * FROM actor_category_films LIMIT 10')
# Out:
# Executando query:
# ('PENELOPE', 'GUINESS', 'Animation:ANACONDA CONFESSIONS')
# ('PENELOPE', 'GUINESS', 'Children:LANGUAGE COWBOY')
# ('PENELOPE', 'GUINESS', 'Classics:COLOR PHILADELPHIA,WESTWARD SEABISCUIT')
# ('PENELOPE', 'GUINESS', 'Comedy:VERTIGO NORTHWEST')
# ('PENELOPE', 'GUINESS', 'Documentary:ACADEMY DINOSAUR')
# ('PENELOPE', 'GUINESS', 'Family:KING EVOLUTION,SPLASH GUMP')
# ('PENELOPE', 'GUINESS', 'Foreign:MULHOLLAND BEAST')
# ('PENELOPE', 'GUINESS', 'Games:BULWORTH COMMANDMENTS,HUMAN GRAFFITI')
# ('PENELOPE', 'GUINESS', 'Horror:ELEPHANT TROJAN,LADY STAGE,RULES HUMAN')
# ('PENELOPE', 'GUINESS', 'Music:WIZARD COLDBLOODED')

# %%
db('''
SELECT 
    MIN(first_name), MIN(last_name), GROUP_CONCAT(films SEPARATOR ";") as total_films
FROM
    actor_category_films
GROUP BY
    actor_id
''')
# Out:
# Executando query:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     559                 raw_as_string=raw_as_string,
# --> 560                 query_attrs=self._query_attrs,
#     561             )
#
# MySQLInterfaceError: Unknown column 'actor_id' in 'group statement'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-37-29e54eb8192f> in <module>
#       6 GROUP BY
#       7     actor_id
# ----> 8 ''')
#
# <ipython-input-1-f8cf815155f2> in run_db_query(connection, query, args)
#       8         with connection.cursor() as cursor:
#       9             print('Executando query:')
# ---> 10             cursor.execute(query, args)
#      11             for result in cursor:
#      12                 print(result)
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     278                 raw=self._raw,
#     279                 buffered=self._buffered,
# --> 280                 raw_as_string=self._raw_as_string,
#     281             )
#     282         except MySQLInterfaceError as err:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     563             raise get_mysql_exception(
#     564                 err.errno, msg=err.msg, sqlstate=err.sqlstate
# --> 565             ) from err
#     566         except AttributeError as err:
#     567             addr = (
#
# ProgrammingError: 1054 (42S22): Unknown column 'actor_id' in 'group statement'

# %% [markdown]
# ## Variáveis
#
# Podemos montar uma query que retorne um valor só e armazenar este valor em uma variável, para uso posterior em outras queries. Para isso vamos usar o prefixo '@' para indicar variáveis, e o comando `SELECT ... INTO`.
#
# Exemplo: quais são os filmes "caros" da nossa base sakila? Vamos descobrir quais filmes custam mais que um desvio padrão acima da média de preços de locação.
#
# Primeiro vamos calcular a média e o desvio padrão dos preços de aluguel:

# %%
db('''
SELECT 
    AVG(rental_rate), 
    STDDEV(rental_rate)
INTO 
    @avg_rate, 
    @stddev_rate 
FROM
    film;
''')
# Out:
# Executando query:

# %% [markdown]
# Note que a query não retorna um resultado: o resultado foi armazenado direto nas variáveis `@avg_rate` e `@stddev_rate`. Vamos usar um `SELECT` sem tabelas para ver o resultado:

# %%
db('SELECT @avg_rate, @stddev_rate')
# Out:
# Executando query:
# (Decimal('2.980000000'), 1.6455698101265719)

# %% [markdown]
# Agora podemos selecionar os filmes caros!

# %%
db('''
SELECT 
    title, rental_rate
FROM
    film
WHERE
    rental_rate > @avg_rate + @stddev_rate;
''')
# Out:
# Executando query:
# ('ACE GOLDFINGER', Decimal('4.99'))
# ('AIRPLANE SIERRA', Decimal('4.99'))
# ('AIRPORT POLLOCK', Decimal('4.99'))
# ('ALADDIN CALENDAR', Decimal('4.99'))
# ('ALI FOREVER', Decimal('4.99'))
# ('AMELIE HELLFIGHTERS', Decimal('4.99'))
# ('AMERICAN CIRCUS', Decimal('4.99'))
# ('ANTHEM LUKE', Decimal('4.99'))
# ('APACHE DIVINE', Decimal('4.99'))
# ('APOCALYPSE FLAMINGOS', Decimal('4.99'))
# ('ATTACKS HATE', Decimal('4.99'))
# ('ATTRACTION NEWTON', Decimal('4.99'))
# ('AUTUMN CROW', Decimal('4.99'))
# ('BABY HALL', Decimal('4.99'))
# ('BACKLASH UNDEFEATED', Decimal('4.99'))
# ('BEAST HUNCHBACK', Decimal('4.99'))
# ('BEAUTY GREASE', Decimal('4.99'))
# ('BEHAVIOR RUNAWAY', Decimal('4.99'))
# ('BETRAYED REAR', Decimal('4.99'))
# ('BIKINI BORROWERS', Decimal('4.99'))
# ('BILKO ANONYMOUS', Decimal('4.99'))
# ('BIRCH ANTITRUST', Decimal('4.99'))
# ('BIRD INDEPENDENCE', Decimal('4.99'))
# ('BIRDS PERDITION', Decimal('4.99'))
# ('BLINDNESS GUN', Decimal('4.99'))
# ('BOILED DARES', Decimal('4.99'))
# ('BOOGIE AMELIE', Decimal('4.99'))
# ('BORN SPINAL', Decimal('4.99'))
# ('BOWFINGER GABLES', Decimal('4.99'))
# ('BRANNIGAN SUNRISE', Decimal('4.99'))
# ('BREAKFAST GOLDFINGER', Decimal('4.99'))
# ('BRIGHT ENCOUNTERS', Decimal('4.99'))
# ('BROOKLYN DESERT', Decimal('4.99'))
# ('BUBBLE GROSSE', Decimal('4.99'))
# ('BUCKET BROTHERHOOD', Decimal('4.99'))
# ('CALENDAR GUNFIGHT', Decimal('4.99'))
# ('CALIFORNIA BIRDS', Decimal('4.99'))
# ('CANDLES GRAPES', Decimal('4.99'))
# ('CARIBBEAN LIBERTY', Decimal('4.99'))
# ('CASABLANCA SUPER', Decimal('4.99'))
# ('CASPER DRAGONFLY', Decimal('4.99'))
# ('CASUALTIES ENCINO', Decimal('4.99'))
# ('CAT CONEHEADS', Decimal('4.99'))
# ('CENTER DINOSAUR', Decimal('4.99'))
# ('CHAMBER ITALIAN', Decimal('4.99'))
# ('CHAMPION FLATLINERS', Decimal('4.99'))
# ('CHASING FIGHT', Decimal('4.99'))
# ('CHICAGO NORTH', Decimal('4.99'))
# ('CHINATOWN GLADIATOR', Decimal('4.99'))
# ('CHISUM BEHAVIOR', Decimal('4.99'))
# ('CINCINATTI WHISPERER', Decimal('4.99'))
# ('CLERKS ANGELS', Decimal('4.99'))
# ('CLOSER BANG', Decimal('4.99'))
# ('CLUE GRAIL', Decimal('4.99'))
# ('COLDBLOODED DARLING', Decimal('4.99'))
# ('COMA HEAD', Decimal('4.99'))
# ('COMMAND DARLING', Decimal('4.99'))
# ('COMMANDMENTS EXPRESS', Decimal('4.99'))
# ('CONEHEADS SMOOCHY', Decimal('4.99'))
# ('CONFESSIONS MAGUIRE', Decimal('4.99'))
# ('CONFIDENTIAL INTERVIEW', Decimal('4.99'))
# ('CONNECTICUT TRAMP', Decimal('4.99'))
# ('CONQUERER NUTS', Decimal('4.99'))
# ('CONTROL ANTHEM', Decimal('4.99'))
# ('CONVERSATION DOWNHILL', Decimal('4.99'))
# ('CREEPERS KANE', Decimal('4.99'))
# ('CROSSING DIVORCE', Decimal('4.99'))
# ('CROWDS TELEMARK', Decimal('4.99'))
# ('DADDY PITTSBURGH', Decimal('4.99'))
# ('DAISY MENAGERIE', Decimal('4.99'))
# ('DANGEROUS UPTOWN', Decimal('4.99'))
# ('DARKO DORADO', Decimal('4.99'))
# ('DARLING BREAKING', Decimal('4.99'))
# ('DARN FORRESTER', Decimal('4.99'))
# ('DAUGHTER MADIGAN', Decimal('4.99'))
# ('DAWN POND', Decimal('4.99'))
# ('DAY UNFAITHFUL', Decimal('4.99'))
# ('STONED PUNK', Decimal('4.99'))
# ('DEEP CRUSADE', Decimal('4.99'))
# ('DESERT POSEIDON', Decimal('4.99'))
# ('DESPERATE TRAINSPOTTING', Decimal('4.99'))
# ('DESTINY SATURDAY', Decimal('4.99'))
# ('DETAILS PACKER', Decimal('4.99'))
# ('DEVIL DESIRE', Decimal('4.99'))
# ('DOGMA FAMILY', Decimal('4.99'))
# ('DOORS PRESIDENT', Decimal('4.99'))
# ('DORADO NOTTING', Decimal('4.99'))
# ('DOUBTFIRE LABYRINTH', Decimal('4.99'))
# ('DOZEN LION', Decimal('4.99'))
# ('DRAGONFLY STRANGERS', Decimal('4.99'))
# ('DRIFTER COMMANDMENTS', Decimal('4.99'))
# ('DRIVING POLISH', Decimal('4.99'))
# ('DROP WATERFRONT', Decimal('4.99'))
# ('DUDE BLINDNESS', Decimal('4.99'))
# ('DURHAM PANKY', Decimal('4.99'))
# ('DYING MAKER', Decimal('4.99'))
# ('EAGLES PANKY', Decimal('4.99'))
# ('EARLY HOME', Decimal('4.99'))
# ('EASY GLADIATOR', Decimal('4.99'))
# ('EDGE KISSING', Decimal('4.99'))
# ('ELEMENT FREDDY', Decimal('4.99'))
# ('ELEPHANT TROJAN', Decimal('4.99'))
# ('ELF MURDER', Decimal('4.99'))
# ('ELIZABETH SHANE', Decimal('4.99'))
# ('ENEMY ODDS', Decimal('4.99'))
# ('EVE RESURRECTION', Decimal('4.99'))
# ('EXPECATIONS NATURAL', Decimal('4.99'))
# ('FALCON VOLUME', Decimal('4.99'))
# ('FELLOWSHIP AUTUMN', Decimal('4.99'))
# ('FEVER EMPIRE', Decimal('4.99'))
# ('FIDDLER LOST', Decimal('4.99'))
# ('FIDELITY DEVIL', Decimal('4.99'))
# ('FIRE WOLVES', Decimal('4.99'))
# ('FLAMINGOS CONNECTICUT', Decimal('4.99'))
# ('FLASH WARS', Decimal('4.99'))
# ('FLIGHT LIES', Decimal('4.99'))
# ('FLINTSTONES HAPPINESS', Decimal('4.99'))
# ('FOOL MOCKINGBIRD', Decimal('4.99'))
# ('FORRESTER COMANCHEROS', Decimal('4.99'))
# ('FREDDY STORM', Decimal('4.99'))
# ('FRENCH HOLIDAY', Decimal('4.99'))
# ('FRISCO FORREST', Decimal('4.99'))
# ('FRONTIER CABIN', Decimal('4.99'))
# ('FUGITIVE MAGUIRE', Decimal('4.99'))
# ('GALAXY SWEETHEARTS', Decimal('4.99'))
# ('GAMES BOWFINGER', Decimal('4.99'))
# ('GARDEN ISLAND', Decimal('4.99'))
# ('GHOST GROUNDHOG', Decimal('4.99'))
# ('GLADIATOR WESTWARD', Decimal('4.99'))
# ('GOLD RIVER', Decimal('4.99'))
# ('GOODFELLAS SALUTE', Decimal('4.99'))
# ('GOSFORD DONNIE', Decimal('4.99'))
# ('GRACELAND DYNAMITE', Decimal('4.99'))
# ('GRINCH MASSAGE', Decimal('4.99'))
# ('GROSSE WONDERFUL', Decimal('4.99'))
# ('GROUNDHOG UNCUT', Decimal('4.99'))
# ('GUMP DATE', Decimal('4.99'))
# ('GUYS FALCON', Decimal('4.99'))
# ('HALL CASSIDY', Decimal('4.99'))
# ('HANGING DEEP', Decimal('4.99'))
# ('HANOVER GALAXY', Decimal('4.99'))
# ('HARRY IDAHO', Decimal('4.99'))
# ('HAUNTED ANTITRUST', Decimal('4.99'))
# ('HEAD STRANGER', Decimal('4.99'))
# ('HEARTBREAKERS BRIGHT', Decimal('4.99'))
# ('HEAVENLY GUN', Decimal('4.99'))
# ('HEAVYWEIGHTS BEAST', Decimal('4.99'))
# ('HOLES BRANNIGAN', Decimal('4.99'))
# ('HOLIDAY GAMES', Decimal('4.99'))
# ('HOLLOW JEOPARDY', Decimal('4.99'))
# ('HOME PITY', Decimal('4.99'))
# ('HOTEL HAPPINESS', Decimal('4.99'))
# ('HUNCHBACK IMPOSSIBLE', Decimal('4.99'))
# ('HUSTLER PARTY', Decimal('4.99'))
# ('HYSTERICAL GRAIL', Decimal('4.99'))
# ('IGBY MAKER', Decimal('4.99'))
# ('IMPOSSIBLE PREJUDICE', Decimal('4.99'))
# ('INCH JET', Decimal('4.99'))
# ('INFORMER DOUBLE', Decimal('4.99'))
# ('INNOCENT USUAL', Decimal('4.99'))
# ('INTERVIEW LIAISONS', Decimal('4.99'))
# ('INTOLERABLE INTENTIONS', Decimal('4.99'))
# ('IRON MOON', Decimal('4.99'))
# ('ISHTAR ROCKETEER', Decimal('4.99'))
# ('ITALIAN AFRICAN', Decimal('4.99'))
# ('JERSEY SASSY', Decimal('4.99'))
# ('JET NEIGHBORS', Decimal('4.99'))
# ('JINGLE SAGEBRUSH', Decimal('4.99'))
# ('KING EVOLUTION', Decimal('4.99'))
# ('KISS GLORY', Decimal('4.99'))
# ('KISSING DOLLS', Decimal('4.99'))
# ('LADY STAGE', Decimal('4.99'))
# ('LAMBS CINCINATTI', Decimal('4.99'))
# ('LAWLESS VISION', Decimal('4.99'))
# ('LEAGUE HELLFIGHTERS', Decimal('4.99'))
# ('LEGALLY SECRETARY', Decimal('4.99'))
# ('LIAISONS SWEET', Decimal('4.99'))
# ('LIES TREATMENT', Decimal('4.99'))
# ('LOLA AGENT', Decimal('4.99'))
# ('LOSER HUSTLER', Decimal('4.99'))
# ('MADIGAN DORADO', Decimal('4.99'))
# ('MAIDEN HOME', Decimal('4.99'))
# ('MALTESE HOPE', Decimal('4.99'))
# ('MASSACRE USUAL', Decimal('4.99'))
# ('MATRIX SNOWMAN', Decimal('4.99'))
# ('MEMENTO ZOOLANDER', Decimal('4.99'))
# ('MERMAID INSECTS', Decimal('4.99'))
# ('MIDSUMMER GROUNDHOG', Decimal('4.99'))
# ('MILLION ACE', Decimal('4.99'))
# ('MINDS TRUMAN', Decimal('4.99'))
# ('MINE TITANS', Decimal('4.99'))
# ('MISSION ZOOLANDER', Decimal('4.99'))
# ('MOD SECRETARY', Decimal('4.99'))
# ('MODEL FISH', Decimal('4.99'))
# ('MONSOON CAUSE', Decimal('4.99'))
# ('MOONSHINE CABIN', Decimal('4.99'))
# ('MOONWALKER FOOL', Decimal('4.99'))
# ('MOVIE SHAKESPEARE', Decimal('4.99'))
# ('MUPPET MILE', Decimal('4.99'))
# ('MUSKETEERS WAIT', Decimal('4.99'))
# ('NAME DETECTIVE', Decimal('4.99'))
# ('NIGHTMARE CHILL', Decimal('4.99'))
# ('NORTH TEQUILA', Decimal('4.99'))
# ('NUTS TIES', Decimal('4.99'))
# ('OCTOBER SUBMARINE', Decimal('4.99'))
# ('OPEN AFRICAN', Decimal('4.99'))
# ('OPPOSITE NECKLACE', Decimal('4.99'))
# ('OPUS ICE', Decimal('4.99'))
# ('OUTLAW HANKY', Decimal('4.99'))
# ('PANIC CLUB', Decimal('4.99'))
# ('PANKY SUBMARINE', Decimal('4.99'))
# ('PANTHER REDS', Decimal('4.99'))
# ('PARK CITIZEN', Decimal('4.99'))
# ('PAST SUICIDES', Decimal('4.99'))
# ('PATHS CONTROL', Decimal('4.99'))
# ('PAYCHECK WAIT', Decimal('4.99'))
# ('PEAK FOREVER', Decimal('4.99'))
# ('PELICAN COMFORTS', Decimal('4.99'))
# ('PERDITION FARGO', Decimal('4.99'))
# ('PHILADELPHIA WIFE', Decimal('4.99'))
# ('PINOCCHIO SIMON', Decimal('4.99'))
# ('PITTSBURGH HUNCHBACK', Decimal('4.99'))
# ('PITY BOUND', Decimal('4.99'))
# ('PLATOON INSTINCT', Decimal('4.99'))
# ('PLUTO OLEANDER', Decimal('4.99'))
# ('POSEIDON FOREVER', Decimal('4.99'))
# ('PREJUDICE OLEANDER', Decimal('4.99'))
# ('PRESIDENT BANG', Decimal('4.99'))
# ('PRIVATE DROP', Decimal('4.99'))
# ('PUNK DIVORCE', Decimal('4.99'))
# ('QUEEN LUKE', Decimal('4.99'))
# ('QUILLS BULL', Decimal('4.99'))
# ('RAGE GAMES', Decimal('4.99'))
# ('RAGING AIRPLANE', Decimal('4.99'))
# ('RAINBOW SHOCK', Decimal('4.99'))
# ('RANGE MOONWALKER', Decimal('4.99'))
# ('RECORDS ZORRO', Decimal('4.99'))
# ('REDS POCUS', Decimal('4.99'))
# ('REQUIEM TYCOON', Decimal('4.99'))
# ('RIGHT CRANES', Decimal('4.99'))
# ('ROAD ROXANNE', Decimal('4.99'))
# ('ROCKY WAR', Decimal('4.99'))
# ('ROSES TREASURE', Decimal('4.99'))
# ('RULES HUMAN', Decimal('4.99'))
# ('SABRINA MIDNIGHT', Decimal('4.99'))
# ('SATISFACTION CONFIDENTIAL', Decimal('4.99'))
# ('SATURDAY LAMBS', Decimal('4.99'))
# ('SATURN NAME', Decimal('4.99'))
# ('SCALAWAG DUCK', Decimal('4.99'))
# ('SCARFACE BANG', Decimal('4.99'))
# ('SCHOOL JACKET', Decimal('4.99'))
# ('SCORPION APOLLO', Decimal('4.99'))
# ('SEATTLE EXPECATIONS', Decimal('4.99'))
# ('SECRET GROUNDHOG', Decimal('4.99'))
# ('SECRETARY ROUGE', Decimal('4.99'))
# ('SECRETS PARADISE', Decimal('4.99'))
# ('SENSE GREEK', Decimal('4.99'))
# ('SENSIBILITY REAR', Decimal('4.99'))
# ('SEVEN SWARM', Decimal('4.99'))
# ('SHAWSHANK BUBBLE', Decimal('4.99'))
# ('SHOW LORD', Decimal('4.99'))
# ('SILVERADO GOLDFINGER', Decimal('4.99'))
# ('SISTER FREDDY', Decimal('4.99'))
# ('SLACKER LIAISONS', Decimal('4.99'))
# ('SLEEPING SUSPECTS', Decimal('4.99'))
# ('SLEEPLESS MONSOON', Decimal('4.99'))
# ('SNATCH SLIPPER', Decimal('4.99'))
# ('SOLDIERS EVOLUTION', Decimal('4.99'))
# ('SOMETHING DUCK', Decimal('4.99'))
# ('SPARTACUS CHEAPER', Decimal('4.99'))
# ('SPEED SUIT', Decimal('4.99'))
# ('SPICE SORORITY', Decimal('4.99'))
# ('STAGECOACH ARMAGEDDON', Decimal('4.99'))
# ('STEEL SANTA', Decimal('4.99'))
# ('STEERS ARMAGEDDON', Decimal('4.99'))
# ('STEPMOM DREAM', Decimal('4.99'))
# ('STING PERSONAL', Decimal('4.99'))
# ('STRANGER STRANGERS', Decimal('4.99'))
# ('STRANGERS GRAFFITI', Decimal('4.99'))
# ('STREETCAR INTENTIONS', Decimal('4.99'))
# ('SUBMARINE BED', Decimal('4.99'))
# ('SUGAR WONKA', Decimal('4.99'))
# ('SUICIDES SILENCE', Decimal('4.99'))
# ('SUIT WALLS', Decimal('4.99'))
# ('SUNRISE LEAGUE', Decimal('4.99'))
# ('SUPER WYOMING', Decimal('4.99'))
# ('SWEDEN SHINING', Decimal('4.99'))
# ('TEEN APOLLO', Decimal('4.99'))
# ('TELEGRAPH VOYAGE', Decimal('4.99'))
# ('TEMPLE ATTRACTION', Decimal('4.99'))
# ('TEQUILA PAST', Decimal('4.99'))
# ('TERMINATOR CLUB', Decimal('4.99'))
# ('THIEF PELICAN', Decimal('4.99'))
# ('THIN SAGEBRUSH', Decimal('4.99'))
# ('TIES HUNGER', Decimal('4.99'))
# ('TITANIC BOONDOCK', Decimal('4.99'))
# ('TITANS JERK', Decimal('4.99'))
# ('TORQUE BOUND', Decimal('4.99'))
# ('TOURIST PELICAN', Decimal('4.99'))
# ('TRADING PINOCCHIO', Decimal('4.99'))
# ('TRAFFIC HOBBIT', Decimal('4.99'))
# ('TRAIN BUNCH', Decimal('4.99'))
# ('TRAINSPOTTING STRANGERS', Decimal('4.99'))
# ('TRAP GUYS', Decimal('4.99'))
# ('TRIP NEWTON', Decimal('4.99'))
# ('TRUMAN CRAZY', Decimal('4.99'))
# ('TWISTED PIRATES', Decimal('4.99'))
# ('TYCOON GATHERING', Decimal('4.99'))
# ('UNDEFEATED DALMATIONS', Decimal('4.99'))
# ('USUAL UNTOUCHABLES', Decimal('4.99'))
# ('VAMPIRE WHALE', Decimal('4.99'))
# ('VANILLA DAY', Decimal('4.99'))
# ('VELVET TERMINATOR', Decimal('4.99'))
# ('VIDEOTAPE ARSENIC', Decimal('4.99'))
# ('VILLAIN DESPERATE', Decimal('4.99'))
# ('VIRGIN DAISY', Decimal('4.99'))
# ('VIRTUAL SPOILERS', Decimal('4.99'))
# ('VOLUME HOUSE', Decimal('4.99'))
# ('WAKE JAWS', Decimal('4.99'))
# ('WALLS ARTIST', Decimal('4.99'))
# ('WANDA CHAMBER', Decimal('4.99'))
# ('WAR NOTTING', Decimal('4.99'))
# ('WASH HEAVENLY', Decimal('4.99'))
# ('WATERFRONT DELIVERANCE', Decimal('4.99'))
# ('WEREWOLF LOLA', Decimal('4.99'))
# ('WEST LION', Decimal('4.99'))
# ('WHALE BIKINI', Decimal('4.99'))
# ('WHISPERER GIANT', Decimal('4.99'))
# ('WIFE TURN', Decimal('4.99'))
# ('WITCHES PANIC', Decimal('4.99'))
# ('WIZARD COLDBLOODED', Decimal('4.99'))
# ('WONDERLAND CHRISTMAS', Decimal('4.99'))
# ('WORKING MICROCOSMOS', Decimal('4.99'))
# ('WYOMING STORM', Decimal('4.99'))
# ('YENTL IDAHO', Decimal('4.99'))
# ('ZORRO ARK', Decimal('4.99'))

# %% [markdown]
# ### Vamos praticar

# %% [markdown]
# Use variáveis temporárias para encontrar o ator que mais participou de filmes.

# %% [markdown]
# ## Operador `IN`

# %% [markdown]
# Suponha que desejamos listar todos os filmes dos 3 atores mais populares. Podemos começar listando os 3 atores mais populares:

# %%
db('''
SELECT 
    actor_id, first_name, last_name, COUNT(film_id) AS num_films
FROM
    actor
    INNER JOIN film_actor USING (actor_id)
GROUP BY 
    actor_id
ORDER BY 
    num_films DESC
LIMIT 3
''')
# Out:
# Executando query:
# (107, 'GINA', 'DEGENERES', 42)
# (102, 'WALTER', 'TORN', 41)
# (198, 'MARY', 'KEITEL', 40)

# %% [markdown]
# Vamos criar uma tabela temporária para guardar a informação de `actor_id` desses atores:

# %%
db('DROP TABLE IF EXISTS temp_pop_actors')
db('''
CREATE TEMPORARY TABLE temp_pop_actors
    SELECT first_name, last_name, actor_id FROM
        actor
        INNER JOIN film_actor USING (actor_id)
    GROUP BY 
        actor_id
    ORDER BY 
        COUNT(film_id) DESC
    LIMIT 3
''')
db('''
SELECT * from temp_pop_actors
''')
# Out:
# Executando query:
# Executando query:
# Executando query:
# ('GINA', 'DEGENERES', 107)
# ('WALTER', 'TORN', 102)
# ('MARY', 'KEITEL', 198)

# %% [markdown]
# Por fim, vamos usar essa informação para listar os filmes dos atores populares:

# %%
db('''
SELECT DISTINCT
    title
FROM
    film
    INNER JOIN film_actor USING (film_id)
WHERE
    actor_id IN (SELECT actor_id FROM temp_pop_actors);
''')
# Out:
# Executando query:
# ('BED HIGHBALL',)
# ('CALENDAR GUNFIGHT',)
# ('CHAMBER ITALIAN',)
# ('CHAPLIN LICENSE',)
# ('CHARIOTS CONSPIRACY',)
# ('CLUELESS BUCKET',)
# ('COLDBLOODED DARLING',)
# ('CONEHEADS SMOOCHY',)
# ('DARKNESS WAR',)
# ('DEER VIRGINIAN',)
# ('DOGMA FAMILY',)
# ('ELEPHANT TROJAN',)
# ('EXCITEMENT EVE',)
# ('FRISCO FORREST',)
# ('GANDHI KWAI',)
# ('GOODFELLAS SALUTE',)
# ('GUNFIGHT MOON',)
# ('HALL CASSIDY',)
# ('HEARTBREAKERS BRIGHT',)
# ('HOOK CHARIOTS',)
# ('HYDE DOCTOR',)
# ('IMPACT ALADDIN',)
# ('INDIAN LOVE',)
# ('INTRIGUE WORST',)
# ('LICENSE WEEKEND',)
# ('LOUISIANA HARRY',)
# ('MAGNIFICENT CHITTY',)
# ('METAL ARMAGEDDON',)
# ('MIDNIGHT WESTWARD',)
# ('MOVIE SHAKESPEARE',)
# ('MUMMY CREATURES',)
# ('OPEN AFRICAN',)
# ('SEARCHERS WAIT',)
# ('SEVEN SWARM',)
# ('SIERRA DIVIDE',)
# ('SPIRITED CASUALTIES',)
# ('STORM HAPPINESS',)
# ('SUGAR WONKA',)
# ('TELEGRAPH VOYAGE',)
# ('TRAINSPOTTING STRANGERS',)
# ('WIFE TURN',)
# ('WINDOW SIDE',)
# ('AMELIE HELLFIGHTERS',)
# ('ARABIA DOGMA',)
# ('BANG KWAI',)
# ('CASABLANCA SUPER',)
# ('CASPER DRAGONFLY',)
# ('CROW GREASE',)
# ('CURTAIN VIDEOTAPE',)
# ('DANCES NONE',)
# ('EARLY HOME',)
# ('FLYING HOOK',)
# ('FORREST SONS',)
# ('FREDDY STORM',)
# ('GASLIGHT CRUSADE',)
# ('HOBBIT ALIEN',)
# ('HOOSIERS BIRDCAGE',)
# ('HYSTERICAL GRAIL',)
# ('JERSEY SASSY',)
# ('LAMBS CINCINATTI',)
# ('LESSON CLEOPATRA',)
# ('LIES TREATMENT',)
# ('LOCK REAR',)
# ('LONELY ELEPHANT',)
# ('MADISON TRAP',)
# ('MOTIONS DETAILS',)
# ('MULHOLLAND BEAST',)
# ('NIGHTMARE CHILL',)
# ('NOVOCAINE FLIGHT',)
# ('RAIDERS ANTITRUST',)
# ('REUNION WITCHES',)
# ('ROOTS REMEMBER',)
# ('SKY MIRACLE',)
# ('SLUMS DUCK',)
# ('SPIKING ELEMENT',)
# ('STAGE WORLD',)
# ('STEPMOM DREAM',)
# ('STRANGELOVE DESIRE',)
# ('WARDROBE PHANTOM',)
# ('WITCHES PANIC',)
# ('WIZARD COLDBLOODED',)
# ('ACADEMY DINOSAUR',)
# ('BUTTERFLY CHOCOLAT',)
# ('CASSIDY WYOMING',)
# ('CRAFT OUTFIELD',)
# ('DUMBO LUST',)
# ('DWARFS ALTER',)
# ('FANTASY TROOPERS',)
# ('FEUD FROGMEN',)
# ('FICTION CHRISTMAS',)
# ('GAMES BOWFINGER',)
# ('GREEDY ROOTS',)
# ('HANDICAP BOONDOCK',)
# ('HAUNTING PIANIST',)
# ('IDOLS SNATCHERS',)
# ('INTENTIONS EMPIRE',)
# ('JEOPARDY ENCINO',)
# ('KING EVOLUTION',)
# ('LOVELY JINGLE',)
# ('LUKE MUMMY',)
# ('MADNESS ATTACKS',)
# ('MALLRATS UNITED',)
# ('MEMENTO ZOOLANDER',)
# ('MERMAID INSECTS',)
# ('MODEL FISH',)
# ('MOONWALKER FOOL',)
# ('NORTHWEST POLISH',)
# ('ROSES TREASURE',)
# ('SAINTS BRIDE',)
# ('SLEEPY JAPANESE',)
# ('SOLDIERS EVOLUTION',)
# ('STEEL SANTA',)
# ('SUBMARINE BED',)
# ('SWEDEN SHINING',)
# ('THEORY MERMAID',)
# ('TITANIC BOONDOCK',)
# ('UNFORGIVEN ZOOLANDER',)
# ('WAGON JAWS',)
# ('YOUTH KICK',)

# %% [markdown]
# Note o uso de *subqueries*!
#
# Não se esqueça de limpar tudo no final!

# %%
db('DROP TABLE temp_pop_actors')
# Out:
# Executando query:

# %% [markdown]
# ### Vamos praticar

# %% [markdown]
# Liste os atores que participaram dos 3 filmes mais rentáveis (aqueles que mais geraram receita para a locadora).

# %%
db('DROP TABLE IF EXISTS filmes_rentaveis')


db('''
CREATE TEMPORARY TABLE filmes_rentaveis
    SELECT 
        film_id, SUM(amount) AS totalPreco
    FROM
        payment
        INNER JOIN rental USING (rental_id)
        INNER JOIN inventory USING (inventory_id)
    GROUP BY 
        film_id
    ORDER BY 
        totalPreco DESC
    LIMIT 3
''')

db(''' SELECT * FROM filmes_rentaveis''')
# Out:
# Executando query:
# Executando query:
# Executando query:
# (879, Decimal('231.73'))
# (973, Decimal('223.69'))
# (1000, Decimal('214.69'))

# %%
db('''
SELECT DISTINCT
    first_name, last_name
FROM
    actor
    INNER JOIN film_actor USING (actor_id)
WHERE
    film_id IN (SELECT film_id FROM filmes_rentaveis);

''')
# Out:
# Executando query:
# ('WOODY', 'HOFFMAN')
# ('CARMEN', 'HUNT')
# ('GINA', 'DEGENERES')
# ('LUCILLE', 'DEE')
# ('VIVIEN', 'BASINGER')
# ('MICHAEL', 'BENING')
# ('THORA', 'TEMPLE')
# ('JULIA', 'BARRYMORE')
# ('CAMERON', 'ZELLWEGER')
# ('GRETA', 'MALDEN')
# ('MICHAEL', 'BOLGER')
# ('IAN', 'TANDY')
# ('NICK', 'DEGENERES')
# ('LISA', 'MONROE')

# %% [markdown]
# ## Subqueries

# %% [markdown]
# Os tópicos discutidos acima poderiam ser resolvidos, em grande parte, com subqueries. As subqueries são queries `SELECT` criadas dentro de outras queries.
#
# Poderíamos ter usado subqueries nos mesmos lugares onde usamos tabelas temporárias, nos tópicos acima. Quando a subquery pode ser transformada em uma tabela temporária independente, separada da query exterior, dizemos que a subquery é **não-correlacionada** com a query exterior.
#
# Usar subqueries não-correlacionadas é um tópico controverso: podemos sempre usar uma tabela temporária ou, ás vezes, pensar em um `JOIN` simples. Aliás, muitas vezes o otimizador de queries do banco de dados transformará a subquery em `JOIN`, se isso for vantajoso em termos de desempenho.
#
# Uma subquery que depende da query externa (e portanto não pode ser separada em uma tabela temporária independente) é chamada de **subquery correlacionada**. Nestes casos podemos ter que executar a subquery para cada linha da query exterior!

# %% [markdown]
# ### Vamos praticar

# %% [markdown]
# Vamos refazer a atividade dos filmes de atores populares, usando subqueries.
#
# Temos um problema: o MySQL não suporta ``LIMIT`` em subqueries com o operador ``IN``. Vamos investigar isso mais de perto.
#
# Em primeiro lugar faça uma tradução direta da implementação da atividade anterior trocando tabela temporária por subquery.

# %%
try:
    db('''
    SELECT 
        actor_id, first_name, last_name
    FROM
        actor
        INNER JOIN film_actor USING (actor_id)
    WHERE
        film_actor.film_id IN (
            SELECT 
                film_id
            FROM
                film
                INNER JOIN inventory USING (film_id)
                INNER JOIN rental USING (inventory_id)
                INNER JOIN payment USING (rental_id)
            WHERE
                payment_date IS NOT NULL
            GROUP BY 
                film_id
            ORDER BY 
                SUM(amount)
            LIMIT 
                3)
    ORDER BY 
        actor_id
    ''')
except mysql.connector.ProgrammingError as e:
    print(f'ProgrammingError: {e}')
# Out:
# Executando query:
# ProgrammingError: 1235 (42000): This version of MySQL doesn't yet support 'LIMIT & IN/ALL/ANY/SOME subquery'

# %% [markdown]
# Ok, apareceu o problema. Mas considere que o problema original não precisava de IN desde o começo! Construa essa solução.

# %% [markdown]
# # `UNION`
#
# Quando duas tabelas tem **EXATAMENTE** as mesmas colunas, podemos concatená-las e formar uma grande tabela unificada usando o operador `UNION`. Por exemplo: suponha que desejamos montar uma lista dos nomes e sobrenomes de todos os clientes E de todos os funcionários. Eis uma solução possível:

# %%
db('DROP TABLE IF EXISTS nomes_clientes')
db('''
CREATE TEMPORARY TABLE nomes_clientes 
    SELECT first_name, last_name FROM customer
''')
# Out:
# Executando query:
# Executando query:

# %%
db('DESCRIBE nomes_clientes')
db('SELECT * FROM nomes_clientes LIMIT 5')
# Out:
# Executando query:
# ('first_name', 'varchar(45)', 'NO', '', None, 'NULL')
# ('last_name', 'varchar(45)', 'NO', '', None, 'NULL')
# Executando query:
# ('MARY', 'SMITH')
# ('PATRICIA', 'JOHNSON')
# ('LINDA', 'WILLIAMS')
# ('BARBARA', 'JONES')
# ('ELIZABETH', 'BROWN')

# %%
db('DROP TABLE IF EXISTS nomes_staff')
db('''
CREATE TEMPORARY TABLE nomes_staff 
    SELECT first_name, last_name FROM staff
''')
# Out:
# Executando query:
# Executando query:

# %%
db('DESCRIBE nomes_staff')
db('SELECT * FROM nomes_staff LIMIT 5')
# Out:
# Executando query:
# ('first_name', 'varchar(45)', 'NO', '', None, 'NULL')
# ('last_name', 'varchar(45)', 'NO', '', None, 'NULL')
# Executando query:
# ('Mike', 'Hillyer')
# ('Jon', 'Stephens')

# %%
db('DROP TABLE IF EXISTS nomes_all')
db('''
CREATE TEMPORARY TABLE nomes_all 
    (SELECT * FROM nomes_staff) 
    UNION 
    (SELECT * FROM nomes_clientes)
''')
# Out:
# Executando query:
# Executando query:

# %%
db('DESCRIBE nomes_all')
db('SELECT * FROM nomes_all LIMIT 5')
# Out:
# Executando query:
# ('first_name', 'varchar(45)', 'NO', '', '', 'NULL')
# ('last_name', 'varchar(45)', 'NO', '', '', 'NULL')
# Executando query:
# ('Mike', 'Hillyer')
# ('Jon', 'Stephens')
# ('MARY', 'SMITH')
# ('PATRICIA', 'JOHNSON')
# ('LINDA', 'WILLIAMS')

# %%
db('DROP TABLE IF EXISTS nomes_clientes')
db('DROP TABLE IF EXISTS nomes_staff')
db('DROP TABLE IF EXISTS nomes_all')

# %% [markdown]
# **Vamos praticar:** refaça o exemplo acima mas use *subqueries* ao invés de *temp tables*.

# %% [markdown]
# ## Desafios!

# %% [markdown]
# Faça uma lista de filmes que tenham mais de dois atores cujo nome inicia com a mesma letra do título do filme!

# %%
db('''
SELECT 
    first_name, last_name, film_id, title
FROM
    actor 
    INNER JOIN film_actor USING (actor_id)
    INNER JOIN film USING (film_id)
GROUP BY
    film_id
''')
# Out:
# Executando query:
# ('PENELOPE', 'GUINESS', 1, 'ACADEMY DINOSAUR')
# ('PENELOPE', 'GUINESS', 23, 'ANACONDA CONFESSIONS')
# ('PENELOPE', 'GUINESS', 25, 'ANGELS LIFE')
# ('PENELOPE', 'GUINESS', 106, 'BULWORTH COMMANDMENTS')
# ('PENELOPE', 'GUINESS', 140, 'CHEAPER CLYDE')
# ('PENELOPE', 'GUINESS', 166, 'COLOR PHILADELPHIA')
# ('PENELOPE', 'GUINESS', 277, 'ELEPHANT TROJAN')
# ('PENELOPE', 'GUINESS', 361, 'GLEAMING JAWBREAKER')
# ('PENELOPE', 'GUINESS', 438, 'HUMAN GRAFFITI')
# ('PENELOPE', 'GUINESS', 499, 'KING EVOLUTION')
# ('PENELOPE', 'GUINESS', 506, 'LADY STAGE')
# ('PENELOPE', 'GUINESS', 509, 'LANGUAGE COWBOY')
# ('PENELOPE', 'GUINESS', 605, 'MULHOLLAND BEAST')
# ('PENELOPE', 'GUINESS', 635, 'OKLAHOMA JUMANJI')
# ('PENELOPE', 'GUINESS', 749, 'RULES HUMAN')
# ('PENELOPE', 'GUINESS', 832, 'SPLASH GUMP')
# ('PENELOPE', 'GUINESS', 939, 'VERTIGO NORTHWEST')
# ('PENELOPE', 'GUINESS', 970, 'WESTWARD SEABISCUIT')
# ('PENELOPE', 'GUINESS', 980, 'WIZARD COLDBLOODED')
# ('NICK', 'WAHLBERG', 3, 'ADAPTATION HOLES')
# ('NICK', 'WAHLBERG', 31, 'APACHE DIVINE')
# ('NICK', 'WAHLBERG', 47, 'BABY HALL')
# ('NICK', 'WAHLBERG', 105, 'BULL SHAWSHANK')
# ('NICK', 'WAHLBERG', 132, 'CHAINSAW UPTOWN')
# ('NICK', 'WAHLBERG', 145, 'CHISUM BEHAVIOR')
# ('NICK', 'WAHLBERG', 226, 'DESTINY SATURDAY')
# ('NICK', 'WAHLBERG', 249, 'DRACULA CRYSTAL')
# ('NICK', 'WAHLBERG', 314, 'FIGHT JAWBREAKER')
# ('NICK', 'WAHLBERG', 321, 'FLASH WARS')
# ('NICK', 'WAHLBERG', 357, 'GILBERT PELICAN')
# ('NICK', 'WAHLBERG', 369, 'GOODFELLAS SALUTE')
# ('NICK', 'WAHLBERG', 399, 'HAPPINESS UNITED')
# ('NICK', 'WAHLBERG', 458, 'INDIAN LOVE')
# ('NICK', 'WAHLBERG', 481, 'JEKYLL FROGMEN')
# ('NICK', 'WAHLBERG', 485, 'JERSEY SASSY')
# ('NICK', 'WAHLBERG', 518, 'LIAISONS SWEET')
# ('NICK', 'WAHLBERG', 540, 'LUCKY FLYING')
# ('NICK', 'WAHLBERG', 550, 'MAGUIRE APACHE')
# ('NICK', 'WAHLBERG', 555, 'MALLRATS UNITED')
# ('NICK', 'WAHLBERG', 561, 'MASK PEACH')
# ('NICK', 'WAHLBERG', 742, 'ROOF CHAMPION')
# ('NICK', 'WAHLBERG', 754, 'RUSHMORE MERMAID')
# ('NICK', 'WAHLBERG', 811, 'SMILE EARRING')
# ('NICK', 'WAHLBERG', 958, 'WARDROBE PHANTOM')
# ('ED', 'CHASE', 17, 'ALONE TRIP')
# ('ED', 'CHASE', 40, 'ARMY FLINTSTONES')
# ('ED', 'CHASE', 42, 'ARTIST COLDBLOODED')
# ('ED', 'CHASE', 87, 'BOONDOCK BALLROOM')
# ('ED', 'CHASE', 111, 'CADDYSHACK JEDI')
# ('ED', 'CHASE', 185, 'COWBOY DOOM')
# ('ED', 'CHASE', 289, 'EVE RESURRECTION')
# ('ED', 'CHASE', 329, 'FORREST SONS')
# ('ED', 'CHASE', 336, 'FRENCH HOLIDAY')
# ('ED', 'CHASE', 341, 'FROST HEAD')
# ('ED', 'CHASE', 393, 'HALLOWEEN NUTS')
# ('ED', 'CHASE', 441, 'HUNTER ALTER')
# ('ED', 'CHASE', 453, 'IMAGE PRINCESS')
# ('ED', 'CHASE', 480, 'JEEPERS WEDDING')
# ('ED', 'CHASE', 539, 'LUCK OPUS')
# ('ED', 'CHASE', 618, 'NECKLACE OUTBREAK')
# ('ED', 'CHASE', 685, 'PLATOON INSTINCT')
# ('ED', 'CHASE', 827, 'SPICE SORORITY')
# ('ED', 'CHASE', 966, 'WEDDING APOLLO')
# ('ED', 'CHASE', 967, 'WEEKEND PERSONAL')
# ('ED', 'CHASE', 971, 'WHALE BIKINI')
# ('ED', 'CHASE', 996, 'YOUNG LANGUAGE')
# ('JENNIFER', 'DAVIS', 56, 'BAREFOOT MANCHURIAN')
# ('JENNIFER', 'DAVIS', 62, 'BED HIGHBALL')
# ('JENNIFER', 'DAVIS', 79, 'BLADE POLISH')
# ('JENNIFER', 'DAVIS', 355, 'GHOSTBUSTERS ELF')
# ('JENNIFER', 'DAVIS', 379, 'GREEDY ROOTS')
# ('JENNIFER', 'DAVIS', 398, 'HANOVER GALAXY')
# ('JENNIFER', 'DAVIS', 463, 'INSTINCT AIRPORT')
# ('JENNIFER', 'DAVIS', 490, 'JUMANJI BLADE')
# ('JENNIFER', 'DAVIS', 616, 'NATIONAL STORY')
# ('JENNIFER', 'DAVIS', 691, 'POSEIDON FOREVER')
# ('JENNIFER', 'DAVIS', 712, 'RAIDERS ANTITRUST')
# ('JENNIFER', 'DAVIS', 714, 'RANDOM GO')
# ('JENNIFER', 'DAVIS', 721, 'REDS POCUS')
# ('JENNIFER', 'DAVIS', 798, 'SILVERADO GOLDFINGER')
# ('JENNIFER', 'DAVIS', 858, 'SUBMARINE BED')
# ('JENNIFER', 'DAVIS', 909, 'TREASURE COMMAND')
# ('JENNIFER', 'DAVIS', 924, 'UNFORGIVEN ZOOLANDER')
# ('JOHNNY', 'LOLLOBRIGIDA', 19, 'AMADEUS HOLY')
# ('JOHNNY', 'LOLLOBRIGIDA', 54, 'BANGER PINOCCHIO')
# ('JOHNNY', 'LOLLOBRIGIDA', 85, 'BONNIE HOLOCAUST')
# ('JOHNNY', 'LOLLOBRIGIDA', 146, 'CHITTY LOCK')
# ('JOHNNY', 'LOLLOBRIGIDA', 171, 'COMMANDMENTS EXPRESS')
# ('JOHNNY', 'LOLLOBRIGIDA', 172, 'CONEHEADS SMOOCHY')
# ('JOHNNY', 'LOLLOBRIGIDA', 202, 'DADDY PITTSBURGH')
# ('JOHNNY', 'LOLLOBRIGIDA', 203, 'DAISY MENAGERIE')
# ('JOHNNY', 'LOLLOBRIGIDA', 286, 'ENOUGH RAGING')
# ('JOHNNY', 'LOLLOBRIGIDA', 288, 'ESCAPE METROPOLIS')
# ('JOHNNY', 'LOLLOBRIGIDA', 316, 'FIRE WOLVES')
# ('JOHNNY', 'LOLLOBRIGIDA', 340, 'FRONTIER CABIN')
# ('JOHNNY', 'LOLLOBRIGIDA', 375, 'GRAIL FRANKENSTEIN')
# ('JOHNNY', 'LOLLOBRIGIDA', 383, 'GROOVE FICTION')
# ('JOHNNY', 'LOLLOBRIGIDA', 392, 'HALL CASSIDY')
# ('JOHNNY', 'LOLLOBRIGIDA', 411, 'HEAVENLY GUN')
# ('JOHNNY', 'LOLLOBRIGIDA', 503, 'KRAMER CHOCOLATE')
# ('JOHNNY', 'LOLLOBRIGIDA', 535, 'LOVE SUICIDES')
# ('JOHNNY', 'LOLLOBRIGIDA', 571, 'METAL ARMAGEDDON')
# ('JOHNNY', 'LOLLOBRIGIDA', 650, 'PACIFIC AMISTAD')
# ('JOHNNY', 'LOLLOBRIGIDA', 665, 'PATTON INTERVIEW')
# ('JOHNNY', 'LOLLOBRIGIDA', 687, 'POCUS PULP')
# ('JOHNNY', 'LOLLOBRIGIDA', 730, 'RIDGEMONT SUBMARINE')
# ('JOHNNY', 'LOLLOBRIGIDA', 732, 'RINGS HEARTBREAKERS')
# ('JOHNNY', 'LOLLOBRIGIDA', 817, 'SOLDIERS EVOLUTION')
# ('JOHNNY', 'LOLLOBRIGIDA', 841, 'STAR OPERATION')
# ('JOHNNY', 'LOLLOBRIGIDA', 865, 'SUNRISE LEAGUE')
# ('BETTE', 'NICHOLSON', 29, 'ANTITRUST TOMATOES')
# ('BETTE', 'NICHOLSON', 53, 'BANG KWAI')
# ('BETTE', 'NICHOLSON', 60, 'BEAST HUNCHBACK')
# ('BETTE', 'NICHOLSON', 70, 'BIKINI BORROWERS')
# ('BETTE', 'NICHOLSON', 112, 'CALENDAR GUNFIGHT')
# ('BETTE', 'NICHOLSON', 164, 'COAST RAINBOW')
# ('BETTE', 'NICHOLSON', 165, 'COLDBLOODED DARLING')
# ('BETTE', 'NICHOLSON', 193, 'CROSSROADS CASUALTIES')
# ('BETTE', 'NICHOLSON', 256, 'DROP WATERFRONT')
# ('BETTE', 'NICHOLSON', 451, 'IGBY MAKER')
# ('BETTE', 'NICHOLSON', 517, 'LESSON CLEOPATRA')
# ('BETTE', 'NICHOLSON', 519, 'LIBERTY MAGNIFICENT')
# ('BETTE', 'NICHOLSON', 692, 'POTLUCK MIXED')
# ('BETTE', 'NICHOLSON', 826, 'SPEED SUIT')
# ('BETTE', 'NICHOLSON', 892, 'TITANIC BOONDOCK')
# ('BETTE', 'NICHOLSON', 902, 'TRADING PINOCCHIO')
# ('BETTE', 'NICHOLSON', 994, 'WYOMING STORM')
# ('GRACE', 'MOSTEL', 27, 'ANONYMOUS HUMAN')
# ('GRACE', 'MOSTEL', 35, 'ARACHNOPHOBIA ROLLERCOASTER')
# ('GRACE', 'MOSTEL', 67, 'BERETS AGENT')
# ('GRACE', 'MOSTEL', 96, 'BREAKING HOME')
# ('GRACE', 'MOSTEL', 170, 'COMMAND DARLING')
# ('GRACE', 'MOSTEL', 173, 'CONFESSIONS MAGUIRE')
# ('GRACE', 'MOSTEL', 217, 'STONED PUNK')
# ('GRACE', 'MOSTEL', 218, 'DECEIVER BETRAYED')
# ('GRACE', 'MOSTEL', 225, 'DESTINATION JERK')
# ('GRACE', 'MOSTEL', 292, 'EXCITEMENT EVE')
# ('GRACE', 'MOSTEL', 351, 'GASLIGHT CRUSADE')
# ('GRACE', 'MOSTEL', 414, 'HELLFIGHTERS SIERRA')
# ('GRACE', 'MOSTEL', 554, 'MALKOVICH PET')
# ('GRACE', 'MOSTEL', 633, 'OCTOBER SUBMARINE')
# ('GRACE', 'MOSTEL', 637, 'OPEN AFRICAN')
# ('GRACE', 'MOSTEL', 758, 'SAINTS BRIDE')
# ('GRACE', 'MOSTEL', 766, 'SAVANNAH TOWN')
# ('GRACE', 'MOSTEL', 770, 'SCISSORHANDS SLUMS')
# ('GRACE', 'MOSTEL', 805, 'SLEEPLESS MONSOON')
# ('GRACE', 'MOSTEL', 806, 'SLEEPY JAPANESE')
# ('GRACE', 'MOSTEL', 846, 'STING PERSONAL')
# ('GRACE', 'MOSTEL', 900, 'TOWN ARK')
# ('GRACE', 'MOSTEL', 901, 'TRACY CIDER')
# ('GRACE', 'MOSTEL', 910, 'TREATMENT JEKYLL')
# ('GRACE', 'MOSTEL', 957, 'WAR NOTTING')
# ('GRACE', 'MOSTEL', 959, 'WARLOCK WEREWOLF')
# ('MATTHEW', 'JOHANSSON', 115, 'CAMPUS REMEMBER')
# ('MATTHEW', 'JOHANSSON', 158, 'CLONES PINOCCHIO')
# ('MATTHEW', 'JOHANSSON', 179, 'CONQUERER NUTS')
# ('MATTHEW', 'JOHANSSON', 195, 'CROWDS TELEMARK')
# ('MATTHEW', 'JOHANSSON', 205, 'DANCES NONE')
# ('MATTHEW', 'JOHANSSON', 255, 'DRIVING POLISH')
# ('MATTHEW', 'JOHANSSON', 263, 'DURHAM PANKY')
# ('MATTHEW', 'JOHANSSON', 396, 'HANGING DEEP')
# ('MATTHEW', 'JOHANSSON', 523, 'LIGHTS DEER')
# ('MATTHEW', 'JOHANSSON', 532, 'LOSER HUSTLER')
# ('MATTHEW', 'JOHANSSON', 752, 'RUNNER MADIGAN')
# ('MATTHEW', 'JOHANSSON', 769, 'SCHOOL JACKET')
# ('MATTHEW', 'JOHANSSON', 771, 'SCORPION APOLLO')
# ('MATTHEW', 'JOHANSSON', 859, 'SUGAR WONKA')
# ('MATTHEW', 'JOHANSSON', 895, 'TOMORROW HUSTLER')
# ('MATTHEW', 'JOHANSSON', 936, 'VANISHING ROCKY')
# ('JOE', 'SWANK', 30, 'ANYTHING SAVANNAH')
# ('JOE', 'SWANK', 74, 'BIRCH ANTITRUST')
# ('JOE', 'SWANK', 147, 'CHOCOLAT HARRY')
# ('JOE', 'SWANK', 148, 'CHOCOLATE DUCK')
# ('JOE', 'SWANK', 191, 'CROOKED FROGMEN')
# ('JOE', 'SWANK', 200, 'CURTAIN VIDEOTAPE')
# ('JOE', 'SWANK', 204, 'DALMATIONS SWEDEN')
# ('JOE', 'SWANK', 434, 'HORROR REIGN')
# ('JOE', 'SWANK', 510, 'LAWLESS VISION')
# ('JOE', 'SWANK', 514, 'LEBOWSKI SOLDIERS')
# ('JOE', 'SWANK', 552, 'MAJESTIC FLOATS')
# ('JOE', 'SWANK', 671, 'PERDITION FARGO')
# ('JOE', 'SWANK', 697, 'PRIMARY GLASS')
# ('JOE', 'SWANK', 722, 'REEF SALUTE')
# ('JOE', 'SWANK', 815, 'SNATCHERS MONTEZUMA')
# ('JOE', 'SWANK', 873, 'SWEETHEARTS SUSPECTS')
# ('JOE', 'SWANK', 889, 'TIES HUNGER')
# ('JOE', 'SWANK', 903, 'TRAFFIC HOBBIT')
# ('JOE', 'SWANK', 926, 'UNTOUCHABLES SUNRISE')
# ('JOE', 'SWANK', 964, 'WATERFRONT DELIVERANCE')
# ('JOE', 'SWANK', 974, 'WILD APOLLO')
# ('CHRISTIAN', 'GABLE', 9, 'ALABAMA DEVIL')
# ('CHRISTIAN', 'GABLE', 236, 'DIVINE RESURRECTION')
# ('CHRISTIAN', 'GABLE', 251, 'DRAGONFLY STRANGERS')
# ('CHRISTIAN', 'GABLE', 366, 'GOLDFINGER SENSIBILITY')
# ('CHRISTIAN', 'GABLE', 477, 'JAWBREAKER BROOKLYN')
# ('CHRISTIAN', 'GABLE', 522, 'LIFE TWISTED')
# ('CHRISTIAN', 'GABLE', 530, 'LORD ARIZONA')
# ('CHRISTIAN', 'GABLE', 587, 'MOD SECRETARY')
# ('CHRISTIAN', 'GABLE', 694, 'PREJUDICE OLEANDER')
# ('CHRISTIAN', 'GABLE', 703, 'PUNK DIVORCE')
# ('CHRISTIAN', 'GABLE', 716, 'REAP UNFAITHFUL')
# ('CHRISTIAN', 'GABLE', 782, 'SHAKESPEARE SADDLE')
# ('CHRISTIAN', 'GABLE', 914, 'TROUBLE DATE')
# ('CHRISTIAN', 'GABLE', 929, 'USUAL UNTOUCHABLES')
# ('CHRISTIAN', 'GABLE', 930, 'VACATION BOONDOCK')
# ('CHRISTIAN', 'GABLE', 983, 'WON DARES')
# ('ZERO', 'CAGE', 118, 'CANYON STOCK')
# ('ZERO', 'CAGE', 281, 'ENCINO ELF')
# ('ZERO', 'CAGE', 283, 'ENDING CROWDS')
# ('ZERO', 'CAGE', 348, 'GANDHI KWAI')
# ('ZERO', 'CAGE', 364, 'GODFATHER DIARY')
# ('ZERO', 'CAGE', 395, 'HANDICAP BOONDOCK')
# ('ZERO', 'CAGE', 429, 'HONEY TIES')
# ('ZERO', 'CAGE', 433, 'HORN WORKING')
# ('ZERO', 'CAGE', 567, 'MEET CHOCOLATE')
# ('ZERO', 'CAGE', 597, 'MOONWALKER FOOL')
# ('ZERO', 'CAGE', 636, 'OLEANDER CLUE')
# ('ZERO', 'CAGE', 709, 'RACER EGG')
# ('ZERO', 'CAGE', 850, 'STORY SIDE')
# ('ZERO', 'CAGE', 854, 'STRANGERS GRAFFITI')
# ('ZERO', 'CAGE', 888, 'THIN SAGEBRUSH')
# ('ZERO', 'CAGE', 896, 'TOOTSIE PILOT')
# ('ZERO', 'CAGE', 928, 'UPTOWN YOUNG')
# ('ZERO', 'CAGE', 938, 'VELVET TERMINATOR')
# ('ZERO', 'CAGE', 969, 'WEST LION')
# ('ZERO', 'CAGE', 988, 'WORKER TARZAN')
# ('KARL', 'BERRY', 16, 'ALLEY EVOLUTION')
# ('KARL', 'BERRY', 34, 'ARABIA DOGMA')
# ('KARL', 'BERRY', 37, 'ARIZONA BANG')
# ('KARL', 'BERRY', 91, 'BOUND CHEAPER')
# ('KARL', 'BERRY', 92, 'BOWFINGER GABLES')
# ('KARL', 'BERRY', 107, 'BUNCH MINDS')
# ('KARL', 'BERRY', 155, 'CLEOPATRA DEVIL')
# ('KARL', 'BERRY', 177, 'CONNECTICUT TRAMP')
# ('KARL', 'BERRY', 208, 'DARES PLUTO')
# ('KARL', 'BERRY', 213, 'DATE SPEED')
# ('KARL', 'BERRY', 216, 'DAY UNFAITHFUL')
# ('KARL', 'BERRY', 243, 'DOORS PRESIDENT')
# ('KARL', 'BERRY', 344, 'FURY MURDER')
# ('KARL', 'BERRY', 400, 'HARDLY ROBBERS')
# ('KARL', 'BERRY', 416, 'HIGHBALL POTTER')
# ('KARL', 'BERRY', 420, 'HOLES BRANNIGAN')
# ('KARL', 'BERRY', 457, 'INDEPENDENCE HOTEL')
# ('KARL', 'BERRY', 513, 'LEATHERNECKS DWARFS')
# ('KARL', 'BERRY', 593, 'MONTEREY LABYRINTH')
# ('KARL', 'BERRY', 631, 'NOVOCAINE FLIGHT')
# ('KARL', 'BERRY', 672, 'PERFECT GROOVE')
# ('KARL', 'BERRY', 728, 'REUNION WITCHES')
# ('KARL', 'BERRY', 812, 'SMOKING BARBARELLA')
# ('KARL', 'BERRY', 838, 'STAGECOACH ARMAGEDDON')
# ('KARL', 'BERRY', 871, 'SWEDEN SHINING')
# ('KARL', 'BERRY', 880, 'TELEMARK HEARTBREAKERS')
# ('KARL', 'BERRY', 945, 'VIRGINIAN PLUTO')
# ('UMA', 'WOOD', 45, 'ATTRACTION NEWTON')
# ('UMA', 'WOOD', 110, 'CABIN FLASH')
# ('UMA', 'WOOD', 144, 'CHINATOWN GLADIATOR')
# ('UMA', 'WOOD', 154, 'CLASH FREDDY')
# ('UMA', 'WOOD', 162, 'CLUELESS BUCKET')
# ('UMA', 'WOOD', 254, 'DRIVER ANNIE')
# ('UMA', 'WOOD', 337, 'FRIDA SLIPPER')
# ('UMA', 'WOOD', 346, 'GALAXY SWEETHEARTS')
# ('UMA', 'WOOD', 381, 'GRINCH MASSAGE')
# ('UMA', 'WOOD', 385, 'GROUNDHOG UNCUT')
# ('UMA', 'WOOD', 427, 'HOMEWARD CIDER')
# ('UMA', 'WOOD', 456, 'INCH JET')
# ('UMA', 'WOOD', 515, 'LEGALLY SECRETARY')
# ('UMA', 'WOOD', 524, 'LION UNCUT')
# ('UMA', 'WOOD', 528, 'LOLITA WORLD')
# ('UMA', 'WOOD', 588, 'MODEL FISH')
# ('UMA', 'WOOD', 600, 'MOTIONS DETAILS')
# ('UMA', 'WOOD', 718, 'REBEL AIRPORT')
# ('UMA', 'WOOD', 729, 'RIDER CADDYSHACK')
# ('UMA', 'WOOD', 816, 'SNOWMAN ROLLERCOASTER')
# ('UMA', 'WOOD', 833, 'SPLENDOR PATTON')
# ('UMA', 'WOOD', 843, 'STEEL SANTA')
# ('UMA', 'WOOD', 897, 'TORQUE BOUND')
# ('UMA', 'WOOD', 998, 'ZHIVAGO CORE')
# ('VIVIEN', 'BERGEN', 187, 'CRANES RESERVOIR')
# ('VIVIEN', 'BERGEN', 232, 'DIRTY ACE')
# ('VIVIEN', 'BERGEN', 241, 'DONNIE ALLEY')
# ('VIVIEN', 'BERGEN', 253, 'DRIFTER COMMANDMENTS')
# ('VIVIEN', 'BERGEN', 258, 'DRUMS DYNAMITE')
# ('VIVIEN', 'BERGEN', 284, 'ENEMY ODDS')
# ('VIVIEN', 'BERGEN', 370, 'GORGEOUS BINGO')
# ('VIVIEN', 'BERGEN', 415, 'HIGH ENCINO')
# ('VIVIEN', 'BERGEN', 417, 'HILLS NEIGHBORS')
# ('VIVIEN', 'BERGEN', 418, 'HOBBIT ALIEN')
# ('VIVIEN', 'BERGEN', 454, 'IMPACT ALADDIN')
# ('VIVIEN', 'BERGEN', 472, 'ITALIAN AFRICAN')
# ('VIVIEN', 'BERGEN', 475, 'JAPANESE RUN')
# ('VIVIEN', 'BERGEN', 495, 'KENTUCKIAN GIANT')
# ('VIVIEN', 'BERGEN', 536, 'LOVELY JINGLE')
# ('VIVIEN', 'BERGEN', 537, 'LOVER TRUMAN')
# ('VIVIEN', 'BERGEN', 612, 'MUSSOLINI SPOILERS')
# ('VIVIEN', 'BERGEN', 688, 'POLISH BROOKLYN')
# ('VIVIEN', 'BERGEN', 759, 'SALUTE APOLLO')
# ('VIVIEN', 'BERGEN', 764, 'SATURDAY LAMBS')
# ('VIVIEN', 'BERGEN', 847, 'STOCK GLASS')
# ('VIVIEN', 'BERGEN', 856, 'STREETCAR INTENTIONS')
# ('VIVIEN', 'BERGEN', 890, 'TIGHTS DAWN')
# ('VIVIEN', 'BERGEN', 908, 'TRAP GUYS')
# ('VIVIEN', 'BERGEN', 919, 'TYCOON GATHERING')
# ('VIVIEN', 'BERGEN', 948, 'VOICE PEACH')
# ('CUBA', 'OLIVIER', 89, 'BORROWERS BEDAZZLED')
# ('CUBA', 'OLIVIER', 108, 'BUTCH PANTHER')
# ('CUBA', 'OLIVIER', 125, 'CASSIDY WYOMING')
# ('CUBA', 'OLIVIER', 275, 'EGYPT TENENBAUMS')
# ('CUBA', 'OLIVIER', 280, 'EMPIRE MALKOVICH')
# ('CUBA', 'OLIVIER', 326, 'FLYING HOOK')
# ('CUBA', 'OLIVIER', 342, 'FUGITIVE MAGUIRE')
# ('CUBA', 'OLIVIER', 445, 'HYDE DOCTOR')
# ('CUBA', 'OLIVIER', 500, 'KISS GLORY')
# ('CUBA', 'OLIVIER', 502, 'KNOCK WARLOCK')
# ('CUBA', 'OLIVIER', 541, 'LUKE MUMMY')
# ('CUBA', 'OLIVIER', 553, 'MAKER GABLES')
# ('CUBA', 'OLIVIER', 594, 'MONTEZUMA COMMAND')
# ('CUBA', 'OLIVIER', 626, 'NOON PAPI')
# ('CUBA', 'OLIVIER', 745, 'ROSES TREASURE')
# ('CUBA', 'OLIVIER', 783, 'SHANE DARKNESS')
# ('CUBA', 'OLIVIER', 795, 'SIEGE MADRE')
# ('CUBA', 'OLIVIER', 886, 'THEORY MERMAID')
# ('CUBA', 'OLIVIER', 949, 'VOLCANO TEXAS')
# ('CUBA', 'OLIVIER', 968, 'WEREWOLF LOLA')
# ('CUBA', 'OLIVIER', 985, 'WONDERLAND CHRISTMAS')
# ('FRED', 'COSTNER', 80, 'BLANKET BEVERLY')
# ('FRED', 'COSTNER', 101, 'BROTHERHOOD BLANKET')
# ('FRED', 'COSTNER', 121, 'CAROL TEXAS')
# ('FRED', 'COSTNER', 221, 'DELIVERANCE MULHOLLAND')
# ('FRED', 'COSTNER', 267, 'EAGLES PANKY')
# ('FRED', 'COSTNER', 269, 'EARRING INSTINCT')
# ('FRED', 'COSTNER', 271, 'EASY GLADIATOR')
# ('FRED', 'COSTNER', 287, 'ENTRAPMENT SATISFACTION')
# ('FRED', 'COSTNER', 345, 'GABLES METROPOLIS')
# ('FRED', 'COSTNER', 455, 'IMPOSSIBLE PREJUDICE')
# ('FRED', 'COSTNER', 548, 'MAGNIFICENT CHITTY')
# ('FRED', 'COSTNER', 582, 'MIRACLE VIRTUAL')
# ('FRED', 'COSTNER', 583, 'MISSION ZOOLANDER')
# ('FRED', 'COSTNER', 717, 'REAR TRADING')
# ('FRED', 'COSTNER', 779, 'SENSE GREEK')
# ('HELEN', 'VOIGHT', 119, 'CAPER MOTIONS')
# ('HELEN', 'VOIGHT', 124, 'CASPER DRAGONFLY')
# ('HELEN', 'VOIGHT', 127, 'CAT CONEHEADS')
# ('HELEN', 'VOIGHT', 199, 'CUPBOARD SINNERS')
# ('HELEN', 'VOIGHT', 201, 'CYCLONE FAMILY')
# ('HELEN', 'VOIGHT', 310, 'FEVER EMPIRE')
# ('HELEN', 'VOIGHT', 313, 'FIDELITY DEVIL')
# ('HELEN', 'VOIGHT', 378, 'GREATEST NORTH')
# ('HELEN', 'VOIGHT', 469, 'IRON MOON')
# ('HELEN', 'VOIGHT', 478, 'JAWS HARRY')
# ('HELEN', 'VOIGHT', 521, 'LIES TREATMENT')
# ('HELEN', 'VOIGHT', 573, 'MICROCOSMOS PARADISE')
# ('HELEN', 'VOIGHT', 603, 'MOVIE SHAKESPEARE')
# ('HELEN', 'VOIGHT', 606, 'MUMMY CREATURES')
# ('HELEN', 'VOIGHT', 734, 'ROAD ROXANNE')
# ('HELEN', 'VOIGHT', 794, 'SIDE ARK')
# ('HELEN', 'VOIGHT', 800, 'SINNERS ATLANTIS')
# ('HELEN', 'VOIGHT', 853, 'STRANGER STRANGERS')
# ('HELEN', 'VOIGHT', 874, 'TADPOLE PARK')
# ('DAN', 'TORN', 44, 'ATTACKS HATE')
# ('DAN', 'TORN', 84, 'BOILED DARES')
# ('DAN', 'TORN', 268, 'EARLY HOME')
# ('DAN', 'TORN', 279, 'ELIZABETH SHANE')
# ('DAN', 'TORN', 386, 'GUMP DATE')
# ('DAN', 'TORN', 460, 'INNOCENT USUAL')
# ('DAN', 'TORN', 462, 'INSIDER ARIZONA')
# ('DAN', 'TORN', 484, 'JERK PAYCHECK')
# ('DAN', 'TORN', 808, 'SLING LUKE')
# ('DAN', 'TORN', 842, 'STATE WASTELAND')
# ('DAN', 'TORN', 863, 'SUN CONFESSIONS')
# ('DAN', 'TORN', 883, 'TEQUILA PAST')
# ('DAN', 'TORN', 917, 'TUXEDO MILE')
# ('DAN', 'TORN', 944, 'VIRGIN DAISY')
# ('BOB', 'FAWCETT', 2, 'ACE GOLDFINGER')
# ('BOB', 'FAWCETT', 152, 'CIRCUS YOUTH')
# ('BOB', 'FAWCETT', 182, 'CONTROL ANTHEM')
# ('BOB', 'FAWCETT', 212, 'DARN FORRESTER')
# ('BOB', 'FAWCETT', 266, 'DYNAMITE TARZAN')
# ('BOB', 'FAWCETT', 404, 'HATE HANDICAP')
# ('BOB', 'FAWCETT', 428, 'HOMICIDE PEACH')
# ('BOB', 'FAWCETT', 473, 'JACKET FRISCO')
# ('BOB', 'FAWCETT', 644, 'OSCAR GOLD')
# ('BOB', 'FAWCETT', 670, 'PELICAN COMFORTS')
# ('BOB', 'FAWCETT', 673, 'PERSONAL LADYBUGS')
# ('BOB', 'FAWCETT', 711, 'RAGING AIRPLANE')
# ('BOB', 'FAWCETT', 750, 'RUN PACIFIC')
# ('BOB', 'FAWCETT', 756, 'SADDLE ANTITRUST')
# ('BOB', 'FAWCETT', 785, 'SHAWSHANK BUBBLE')
# ('BOB', 'FAWCETT', 877, 'TAXI KICK')
# ('LUCILLE', 'TRACY', 63, 'BEDAZZLED MARRIED')
# ('LUCILLE', 'TRACY', 231, 'DINOSAUR SECRETARY')
# ('LUCILLE', 'TRACY', 274, 'EGG IGBY')
# ('LUCILLE', 'TRACY', 492, 'JUNGLE CLOSER')
# ('LUCILLE', 'TRACY', 527, 'LOLA AGENT')
# ('LUCILLE', 'TRACY', 531, 'LOSE INCH')
# ('LUCILLE', 'TRACY', 538, 'LOVERBOY ATTACKS')
# ('LUCILLE', 'TRACY', 589, 'MODERN DORADO')
# ('LUCILLE', 'TRACY', 643, 'ORIENT CLOSER')
# ('LUCILLE', 'TRACY', 652, 'PAJAMA JAWBREAKER')
# ('LUCILLE', 'TRACY', 663, 'PATIENT SISTER')
# ('LUCILLE', 'TRACY', 757, 'SAGEBRUSH CLUELESS')
# ('LUCILLE', 'TRACY', 784, 'SHANGHAI TYCOON')
# ('LUCILLE', 'TRACY', 962, 'WASTELAND DIVINE')
# ('LUCILLE', 'TRACY', 977, 'WINDOW SIDE')
# ('KIRSTEN', 'PALTROW', 6, 'AGENT TRUMAN')
# ('KIRSTEN', 'PALTROW', 88, 'BORN SPINAL')
# ('KIRSTEN', 'PALTROW', 142, 'CHICKEN HELLFIGHTERS')
# ('KIRSTEN', 'PALTROW', 159, 'CLOSER BANG')
# ('KIRSTEN', 'PALTROW', 426, 'HOME PITY')
# ('KIRSTEN', 'PALTROW', 497, 'KILL BROTHERHOOD')
# ('KIRSTEN', 'PALTROW', 507, 'LADYBUGS ARMAGEDDON')
# ('KIRSTEN', 'PALTROW', 680, 'PINOCCHIO SIMON')
# ('KIRSTEN', 'PALTROW', 686, 'PLUTO OLEANDER')
# ('KIRSTEN', 'PALTROW', 700, 'PRIX UNDEFEATED')
# ('KIRSTEN', 'PALTROW', 702, 'PULP BEVERLY')
# ('KIRSTEN', 'PALTROW', 733, 'RIVER OUTLAW')
# ('KIRSTEN', 'PALTROW', 804, 'SLEEPING SUSPECTS')
# ('KIRSTEN', 'PALTROW', 887, 'THIEF PELICAN')
# ('KIRSTEN', 'PALTROW', 893, 'TITANS JERK')
# ('KIRSTEN', 'PALTROW', 920, 'UNBREAKABLE KARATE')
# ('ELVIS', 'MARX', 291, 'EVOLUTION ALTER')
# ('ELVIS', 'MARX', 294, 'EXPECATIONS NATURAL')
# ('ELVIS', 'MARX', 349, 'GANGS PRIDE')
# ('ELVIS', 'MARX', 430, 'HOOK CHARIOTS')
# ('ELVIS', 'MARX', 483, 'JERICHO MULAN')
# ('ELVIS', 'MARX', 491, 'JUMPING WRATH')
# ('ELVIS', 'MARX', 634, 'ODDS BOOGIE')
# ('ELVIS', 'MARX', 648, 'OUTLAW HANKY')
# ('ELVIS', 'MARX', 731, 'RIGHT CRANES')
# ('ELVIS', 'MARX', 775, 'SEATTLE EXPECATIONS')
# ('ELVIS', 'MARX', 802, 'SKY MIRACLE')
# ('ELVIS', 'MARX', 912, 'TROJAN TOMORROW')
# ('SANDRA', 'KILMER', 78, 'BLACKOUT PRIVATE')
# ('SANDRA', 'KILMER', 116, 'CANDIDATE PERDITION')
# ('SANDRA', 'KILMER', 117, 'CANDLES GRAPES')
# ('SANDRA', 'KILMER', 235, 'DIVIDE MONSTER')
# ('SANDRA', 'KILMER', 367, 'GOLDMINE TYCOON')
# ('SANDRA', 'KILMER', 419, 'HOCUS FRIDA')
# ('SANDRA', 'KILMER', 435, 'HOTEL HAPPINESS')
# ('SANDRA', 'KILMER', 449, 'IDENTITY LOVER')
# ('SANDRA', 'KILMER', 549, 'MAGNOLIA FORRESTER')
# ('SANDRA', 'KILMER', 649, 'OZ LIAISONS')
# ('SANDRA', 'KILMER', 820, 'SONS INTERVIEW')
# ('SANDRA', 'KILMER', 855, 'STREAK RIDGEMONT')
# ('SANDRA', 'KILMER', 935, 'VANISHED GARDEN')
# ('SANDRA', 'KILMER', 981, 'WOLVES DESIRE')
# ('SANDRA', 'KILMER', 997, 'YOUTH KICK')
# ('CAMERON', 'STREEP', 83, 'BLUES INSTINCT')
# ('CAMERON', 'STREEP', 126, 'CASUALTIES ENCINO')
# ('CAMERON', 'STREEP', 178, 'CONNECTION MICROCOSMOS')
# ('CAMERON', 'STREEP', 194, 'CROW GREASE')
# ('CAMERON', 'STREEP', 242, 'DOOM DANCING')
# ('CAMERON', 'STREEP', 335, 'FREEDOM CLEOPATRA')
# ('CAMERON', 'STREEP', 405, 'HAUNTED ANTITRUST')
# ('CAMERON', 'STREEP', 585, 'MOB DUFFEL')
# ('CAMERON', 'STREEP', 653, 'PANIC CLUB')
# ('CAMERON', 'STREEP', 704, 'PURE RUNNER')
# ('CAMERON', 'STREEP', 781, 'SEVEN SWARM')
# ('CAMERON', 'STREEP', 829, 'SPINAL ROCKY')
# ('KEVIN', 'BLOOM', 21, 'AMERICAN CIRCUS')
# ('KEVIN', 'BLOOM', 86, 'BOOGIE AMELIE')
# ('KEVIN', 'BLOOM', 153, 'CITIZEN SHREK')
# ('KEVIN', 'BLOOM', 245, 'DOUBLE WRATH')
# ('KEVIN', 'BLOOM', 311, 'FICTION CHRISTMAS')
# ('KEVIN', 'BLOOM', 564, 'MASSAGE IMAGE')
# ('KEVIN', 'BLOOM', 755, 'SABRINA MIDNIGHT')
# ('RIP', 'CRAWFORD', 90, 'BOULEVARD MOB')
# ('RIP', 'CRAWFORD', 93, 'BRANNIGAN SUNRISE')
# ('RIP', 'CRAWFORD', 103, 'BUCKET BROTHERHOOD')
# ('RIP', 'CRAWFORD', 186, 'CRAFT OUTFIELD')
# ('RIP', 'CRAWFORD', 327, 'FOOL MOCKINGBIRD')
# ('RIP', 'CRAWFORD', 390, 'GUYS FALCON')
# ('RIP', 'CRAWFORD', 529, 'LONELY ELEPHANT')
# ('RIP', 'CRAWFORD', 544, 'MADISON TRAP')
# ('RIP', 'CRAWFORD', 682, 'PITTSBURGH HUNCHBACK')
# ('RIP', 'CRAWFORD', 715, 'RANGE MOONWALKER')
# ('RIP', 'CRAWFORD', 821, 'SORORITY QUEEN')
# ('RIP', 'CRAWFORD', 885, 'TEXAS WATCH')
# ('RIP', 'CRAWFORD', 904, 'TRAIN BUNCH')
# ('RIP', 'CRAWFORD', 906, 'TRAMP OTHERS')
# ('JULIA', 'MCQUEEN', 150, 'CIDER DESIRE')
# ('JULIA', 'MCQUEEN', 273, 'EFFECT GLADIATOR')
# ('JULIA', 'MCQUEEN', 334, 'FREDDY STORM')
# ('JULIA', 'MCQUEEN', 347, 'GAMES BOWFINGER')
# ('JULIA', 'MCQUEEN', 359, 'GLADIATOR WESTWARD')
# ('JULIA', 'MCQUEEN', 586, 'MOCKINGBIRD HOLLYWOOD')
# ('JULIA', 'MCQUEEN', 679, 'PILOT HOOSIERS')
# ('JULIA', 'MCQUEEN', 695, 'PRESIDENT BANG')
# ('JULIA', 'MCQUEEN', 830, 'SPIRIT FLINTSTONES')
# ('JULIA', 'MCQUEEN', 986, 'WONKA SEA')
# ('WOODY', 'HOFFMAN', 14, 'ALICE FANTASIA')
# ('WOODY', 'HOFFMAN', 43, 'ATLANTIS CAUSE')
# ('WOODY', 'HOFFMAN', 58, 'BEACH HEARTBREAKERS')
# ('WOODY', 'HOFFMAN', 259, 'DUCK RACER')
# ('WOODY', 'HOFFMAN', 358, 'GILMORE BOILED')
# ('WOODY', 'HOFFMAN', 508, 'LAMBS CINCINATTI')
# ('WOODY', 'HOFFMAN', 551, 'MAIDEN HOME')
# ('WOODY', 'HOFFMAN', 574, 'MIDNIGHT WESTWARD')
# ('WOODY', 'HOFFMAN', 619, 'NEIGHBORS CHARADE')
# ('WOODY', 'HOFFMAN', 625, 'NONE SPIKING')
# ('WOODY', 'HOFFMAN', 743, 'ROOM ROMAN')
# ('WOODY', 'HOFFMAN', 790, 'SHOOTIST SUPERFLY')
# ('WOODY', 'HOFFMAN', 793, 'SHRUNK DIVINE')
# ('WOODY', 'HOFFMAN', 835, 'SPY MILE')
# ('WOODY', 'HOFFMAN', 879, 'TELEGRAPH VOYAGE')
# ('WOODY', 'HOFFMAN', 953, 'WAIT CIDER')
# ('WOODY', 'HOFFMAN', 973, 'WIFE TURN')
# ('ALEC', 'WAYNE', 10, 'ALADDIN CALENDAR')
# ('ALEC', 'WAYNE', 131, 'CENTER DINOSAUR')
# ('ALEC', 'WAYNE', 133, 'CHAMBER ITALIAN')
# ('ALEC', 'WAYNE', 282, 'ENCOUNTERS CURTAIN')
# ('ALEC', 'WAYNE', 296, 'EXPRESS LONELY')
# ('ALEC', 'WAYNE', 436, 'HOURS RAGE')
# ('ALEC', 'WAYNE', 444, 'HUSTLER PARTY')
# ('ALEC', 'WAYNE', 482, 'JEOPARDY ENCINO')
# ('ALEC', 'WAYNE', 488, 'JOON NORTHWEST')
# ('ALEC', 'WAYNE', 547, 'MAGIC MALLRATS')
# ('ALEC', 'WAYNE', 590, 'MONEY HAROLD')
# ('ALEC', 'WAYNE', 646, 'OUTBREAK DIVINE')
# ('ALEC', 'WAYNE', 723, 'REIGN GENTLEMEN')
# ('ALEC', 'WAYNE', 862, 'SUMMER SCARFACE')
# ('SANDRA', 'PECK', 64, 'BEETHOVEN EXORCIST')
# ('SANDRA', 'PECK', 69, 'BEVERLY OUTLAW')
# ('SANDRA', 'PECK', 77, 'BIRDS PERDITION')
# ('SANDRA', 'PECK', 260, 'DUDE BLINDNESS')
# ('SANDRA', 'PECK', 262, 'DUMBO LUST')
# ('SANDRA', 'PECK', 301, 'FAMILY SWEET')
# ('SANDRA', 'PECK', 318, 'FIREHOUSE VIETNAM')
# ('SANDRA', 'PECK', 565, 'MATRIX SNOWMAN')
# ('SANDRA', 'PECK', 797, 'SILENCE KANE')
# ('SISSY', 'SOBIESKI', 163, 'CLYDE THEORY')
# ('SISSY', 'SOBIESKI', 188, 'CRAZY HOME')
# ('SISSY', 'SOBIESKI', 299, 'FACTORY DRAGON')
# ('SISSY', 'SOBIESKI', 308, 'FERRIS MOTHER')
# ('SISSY', 'SOBIESKI', 368, 'GONE TROUBLE')
# ('SISSY', 'SOBIESKI', 380, 'GREEK EVERYONE')
# ('SISSY', 'SOBIESKI', 431, 'HOOSIERS BIRDCAGE')
# ('SISSY', 'SOBIESKI', 739, 'ROCKY WAR')
# ('SISSY', 'SOBIESKI', 978, 'WISDOM WORKER')
# ('TIM', 'HACKMAN', 65, 'BEHAVIOR RUNAWAY')
# ('TIM', 'HACKMAN', 136, 'CHAPLIN LICENSE')
# ('TIM', 'HACKMAN', 197, 'CRUSADE HONEY')
# ('TIM', 'HACKMAN', 219, 'DEEP CRUSADE')
# ('TIM', 'HACKMAN', 309, 'FEUD FROGMEN')
# ('TIM', 'HACKMAN', 312, 'FIDDLER LOST')
# ('TIM', 'HACKMAN', 401, 'HAROLD FRENCH')
# ('TIM', 'HACKMAN', 651, 'PACKER MADIGAN')
# ('TIM', 'HACKMAN', 667, 'PEACH INNOCENT')
# ('TIM', 'HACKMAN', 669, 'PEARL DESTINY')
# ('MILLA', 'PECK', 135, 'CHANCE RESURRECTION')
# ('MILLA', 'PECK', 214, 'DAUGHTER MADIGAN')
# ('MILLA', 'PECK', 252, 'DREAM PICKUP')
# ('MILLA', 'PECK', 305, 'FATAL HAUNTED')
# ('MILLA', 'PECK', 306, 'FEATHERS METAL')
# ('MILLA', 'PECK', 489, 'JUGGLER HARDLY')
# ('MILLA', 'PECK', 735, 'ROBBERS JOON')
# ('MILLA', 'PECK', 737, 'ROCK INSTINCT')
# ('MILLA', 'PECK', 878, 'TEEN APOLLO')
# ('MILLA', 'PECK', 881, 'TEMPLE ATTRACTION')
# ('MILLA', 'PECK', 965, 'WATERSHIP FRONTIER')
# ('MILLA', 'PECK', 972, 'WHISPERER GIANT')
# ('MILLA', 'PECK', 993, 'WRONG BEHAVIOR')
# ('AUDREY', 'OLIVIER', 244, 'DORADO NOTTING')
# ('AUDREY', 'OLIVIER', 389, 'GUNFIGHTER MUSSOLINI')
# ('AUDREY', 'OLIVIER', 493, 'KANE EXORCIST')
# ('AUDREY', 'OLIVIER', 525, 'LOATHING LEGALLY')
# ('AUDREY', 'OLIVIER', 668, 'PEAK FOREVER')
# ('AUDREY', 'OLIVIER', 720, 'REDEMPTION COMFORTS')
# ('AUDREY', 'OLIVIER', 788, 'SHIP WONDERLAND')
# ('AUDREY', 'OLIVIER', 836, 'SQUAD FISH')
# ('AUDREY', 'OLIVIER', 950, 'VOLUME HOUSE')
# ('JUDY', 'DEAN', 52, 'BALLROOM MOCKINGBIRD')
# ('JUDY', 'DEAN', 615, 'NASH CHOCOLAT')
# ('JUDY', 'DEAN', 707, 'QUEST MUSSOLINI')
# ('JUDY', 'DEAN', 738, 'ROCKETEER MOTHER')
# ('JUDY', 'DEAN', 748, 'RUGRATS SHAKESPEARE')
# ('BURT', 'DUKAKIS', 15, 'ALIEN CENTER')
# ('BURT', 'DUKAKIS', 81, 'BLINDNESS GUN')
# ('BURT', 'DUKAKIS', 387, 'GUN BONNIE')
# ('BURT', 'DUKAKIS', 410, 'HEAVEN FREEDOM')
# ('BURT', 'DUKAKIS', 466, 'INTOLERABLE INTENTIONS')
# ('BURT', 'DUKAKIS', 569, 'MENAGERIE RUSHMORE')
# ('BURT', 'DUKAKIS', 875, 'TALENTED HOMICIDE')
# ('BURT', 'DUKAKIS', 915, 'TRUMAN CRAZY')
# ('BURT', 'DUKAKIS', 931, 'VALENTINE VANISHING')
# ('BURT', 'DUKAKIS', 956, 'WANDA CHAMBER')
# ('VAL', 'BOLGER', 12, 'ALASKA PHANTOM')
# ('VAL', 'BOLGER', 122, 'CARRIE BUNCH')
# ('VAL', 'BOLGER', 317, 'FIREBALL PHILADELPHIA')
# ('VAL', 'BOLGER', 467, 'INTRIGUE WORST')
# ('VAL', 'BOLGER', 572, 'METROPOLIS COMA')
# ('VAL', 'BOLGER', 662, 'PATHS CONTROL')
# ('VAL', 'BOLGER', 839, 'STALLION SUNDANCE')
# ('VAL', 'BOLGER', 840, 'STAMPEDE DISTURBING')
# ('VAL', 'BOLGER', 925, 'UNITED PILOT')
# ('VAL', 'BOLGER', 963, 'WATCH TRACY')
# ('VAL', 'BOLGER', 989, 'WORKING MICROCOSMOS')
# ('TOM', 'MCKELLEN', 24, 'ANALYZE HOOSIERS')
# ('TOM', 'MCKELLEN', 160, 'CLUB GRAFFITI')
# ('TOM', 'MCKELLEN', 176, 'CONGENIALITY QUEST')
# ('TOM', 'MCKELLEN', 223, 'DESIRE ALIEN')
# ('TOM', 'MCKELLEN', 338, 'FRISCO FORREST')
# ('TOM', 'MCKELLEN', 353, 'GENTLEMEN STAGE')
# ('TOM', 'MCKELLEN', 448, 'IDAHO LOVE')
# ('TOM', 'MCKELLEN', 450, 'IDOLS SNATCHERS')
# ('TOM', 'MCKELLEN', 501, 'KISSING DOLLS')
# ('TOM', 'MCKELLEN', 516, 'LEGEND JEDI')
# ('TOM', 'MCKELLEN', 705, 'PURPLE MOVIE')
# ('TOM', 'MCKELLEN', 876, 'TARZAN VIDEOTAPE')
# ('GOLDIE', 'BRODY', 71, 'BILKO ANONYMOUS')
# ('GOLDIE', 'BRODY', 73, 'BINGO TALENTED')
# ('GOLDIE', 'BRODY', 168, 'COMANCHEROS ENEMY')
# ('GOLDIE', 'BRODY', 222, 'DESERT POSEIDON')
# ('GOLDIE', 'BRODY', 290, 'EVERYONE CRAFT')
# ('GOLDIE', 'BRODY', 293, 'EXORCIST STING')
# ('GOLDIE', 'BRODY', 320, 'FLAMINGOS CONNECTICUT')
# ('GOLDIE', 'BRODY', 425, 'HOLY TADPOLE')
# ('GOLDIE', 'BRODY', 476, 'JASON TRAP')
# ('GOLDIE', 'BRODY', 559, 'MARRIED GO')
# ('GOLDIE', 'BRODY', 598, 'MOSQUITO ARMAGEDDON')
# ('GOLDIE', 'BRODY', 683, 'PITY BOUND')
# ('GOLDIE', 'BRODY', 689, 'POLLOCK DELIVERANCE')
# ('GOLDIE', 'BRODY', 696, 'PRIDE ALAMO')
# ('GOLDIE', 'BRODY', 736, 'ROBBERY BRIGHT')
# ('GOLDIE', 'BRODY', 772, 'SEA VIRGIN')
# ('GOLDIE', 'BRODY', 831, 'SPIRITED CASUALTIES')
# ('JOHNNY', 'CAGE', 11, 'ALAMO VIDEOTAPE')
# ('JOHNNY', 'CAGE', 128, 'CATCH AMISTAD')
# ('JOHNNY', 'CAGE', 233, 'DISCIPLE MOTHER')
# ('JOHNNY', 'CAGE', 374, 'GRAFFITI LOVE')
# ('JOHNNY', 'CAGE', 394, 'HAMLET WISDOM')
# ('JOHNNY', 'CAGE', 494, 'KARATE MOON')
# ('JOHNNY', 'CAGE', 744, 'ROOTS REMEMBER')
# ('JOHNNY', 'CAGE', 747, 'ROXANNE REBEL')
# ('JOHNNY', 'CAGE', 799, 'SIMON NORTH')
# ('JOHNNY', 'CAGE', 868, 'SUPERFLY TRIP')
# ('JOHNNY', 'CAGE', 869, 'SUSPECTS QUILLS')
# ('JOHNNY', 'CAGE', 933, 'VAMPIRE WHALE')
# ('JODIE', 'DEGENERES', 4, 'AFFAIR PREJUDICE')
# ('JODIE', 'DEGENERES', 100, 'BROOKLYN DESERT')
# ('JODIE', 'DEGENERES', 230, 'DIARY PANIC')
# ('JODIE', 'DEGENERES', 596, 'MOONSHINE CABIN')
# ('JODIE', 'DEGENERES', 657, 'PARADISE SABRINA')
# ('JODIE', 'DEGENERES', 674, 'PET HAUNTING')
# ('JODIE', 'DEGENERES', 678, 'PICKUP DRIVING')
# ('JODIE', 'DEGENERES', 724, 'REMEMBER DIARY')
# ('JODIE', 'DEGENERES', 894, 'TOMATOES HELLFIGHTERS')
# ('JODIE', 'DEGENERES', 942, 'VIETNAM SMOOCHY')
# ('TOM', 'MIRANDA', 139, 'CHASING FIGHT')
# ('TOM', 'MIRANDA', 333, 'FREAKY POCUS')
# ('TOM', 'MIRANDA', 505, 'LABYRINTH LEAGUE')
# ('TOM', 'MIRANDA', 546, 'MADRE GABLES')
# ('TOM', 'MIRANDA', 568, 'MEMENTO ZOOLANDER')
# ('TOM', 'MIRANDA', 713, 'RAINBOW SHOCK')
# ('TOM', 'MIRANDA', 861, 'SUIT WALLS')
# ('TOM', 'MIRANDA', 867, 'SUPER WYOMING')
# ('TOM', 'MIRANDA', 907, 'TRANSLATION SUMMER')
# ('TOM', 'MIRANDA', 922, 'UNDEFEATED DALMATIONS')
# ('TOM', 'MIRANDA', 932, 'VALLEY PACKER')
# ('KIRK', 'JOVOVICH', 161, 'CLUE GRAIL')
# ('KIRK', 'JOVOVICH', 180, 'CONSPIRACY SPIRIT')
# ('KIRK', 'JOVOVICH', 239, 'DOGMA FAMILY')
# ('KIRK', 'JOVOVICH', 276, 'ELEMENT FREDDY')
# ('KIRK', 'JOVOVICH', 330, 'FORRESTER COMANCHEROS')
# ('KIRK', 'JOVOVICH', 377, 'GREASE YOUTH')
# ('KIRK', 'JOVOVICH', 533, 'LOST BIRD')
# ('KIRK', 'JOVOVICH', 608, 'MURDER ANTITRUST')
# ('KIRK', 'JOVOVICH', 621, 'NETWORK PEAK')
# ('KIRK', 'JOVOVICH', 753, 'RUSH GOODFELLAS')
# ('NICK', 'STALLONE', 94, 'BRAVEHEART HUMAN')
# ('NICK', 'STALLONE', 109, 'BUTTERFLY CHOCOLAT')
# ('NICK', 'STALLONE', 322, 'FLATLINERS KILLER')
# ('NICK', 'STALLONE', 591, 'MONSOON CAUSE')
# ('NICK', 'STALLONE', 604, 'MULAN MOON')
# ('NICK', 'STALLONE', 699, 'PRIVATE DROP')
# ('NICK', 'STALLONE', 751, 'RUNAWAY TENENBAUMS')
# ('NICK', 'STALLONE', 825, 'SPEAKEASY DATE')
# ('NICK', 'STALLONE', 937, 'VARSITY TRIP')
# ('NICK', 'STALLONE', 952, 'WAGON JAWS')
# ('NICK', 'STALLONE', 982, 'WOMEN DORADO')
# ('REESE', 'KILMER', 18, 'ALTER VICTORY')
# ('REESE', 'KILMER', 66, 'BENEATH RUSH')
# ('REESE', 'KILMER', 198, 'CRYSTAL BREAKING')
# ('REESE', 'KILMER', 407, 'HAWK CHILL')
# ('REESE', 'KILMER', 767, 'SCALAWAG DUCK')
# ('REESE', 'KILMER', 778, 'SECRETS PARADISE')
# ('REESE', 'KILMER', 810, 'SLUMS DUCK')
# ('REESE', 'KILMER', 975, 'WILLOW TRACY')
# ('PARKER', 'GOLDBERG', 38, 'ARK RIDGEMONT')
# ('PARKER', 'GOLDBERG', 51, 'BALLOON HOMEWARD')
# ('PARKER', 'GOLDBERG', 174, 'CONFIDENTIAL INTERVIEW')
# ('PARKER', 'GOLDBERG', 319, 'FISH OPUS')
# ('PARKER', 'GOLDBERG', 768, 'SCARFACE BANG')
# ('PARKER', 'GOLDBERG', 991, 'WORST BANGER')
# ('JULIA', 'BARRYMORE', 36, 'ARGONAUTS TOWN')
# ('JULIA', 'BARRYMORE', 576, 'MIGHTY LUCK')
# ('JULIA', 'BARRYMORE', 777, 'SECRETARY ROUGE')
# ('JULIA', 'BARRYMORE', 787, 'SHINING ROSES')
# ('JULIA', 'BARRYMORE', 913, 'TROOPERS METAL')
# ('JULIA', 'BARRYMORE', 923, 'UNFAITHFUL KILL')
# ('FRANCES', 'DAY-LEWIS', 99, 'BRINGING HYSTERICAL')
# ('FRANCES', 'DAY-LEWIS', 134, 'CHAMPION FLATLINERS')
# ('FRANCES', 'DAY-LEWIS', 211, 'DARLING BREAKING')
# ('FRANCES', 'DAY-LEWIS', 295, 'EXPENDABLE STALLION')
# ('FRANCES', 'DAY-LEWIS', 315, 'FINDING ANACONDA')
# ('FRANCES', 'DAY-LEWIS', 545, 'MADNESS ATTACKS')
# ('FRANCES', 'DAY-LEWIS', 570, 'MERMAID INSECTS')
# ('FRANCES', 'DAY-LEWIS', 599, 'MOTHER OLEANDER')
# ('FRANCES', 'DAY-LEWIS', 645, 'OTHERS SOUP')
# ('FRANCES', 'DAY-LEWIS', 792, 'SHREK LICENSE')
# ('ANNE', 'CRONYN', 151, 'CINCINATTI WHISPERER')
# ('ANNE', 'CRONYN', 207, 'DANGEROUS UPTOWN')
# ('ANNE', 'CRONYN', 250, 'DRAGON SQUAD')
# ('ANNE', 'CRONYN', 391, 'HALF OUTFIELD')
# ('ANNE', 'CRONYN', 423, 'HOLLYWOOD ANONYMOUS')
# ('ANNE', 'CRONYN', 542, 'LUST LOCK')
# ('ANNE', 'CRONYN', 558, 'MANNEQUIN WORST')
# ('ANNE', 'CRONYN', 579, 'MINDS TRUMAN')
# ('ANNE', 'CRONYN', 595, 'MOON BUNCH')
# ('ANNE', 'CRONYN', 725, 'REQUIEM TYCOON')
# ('ANNE', 'CRONYN', 927, 'UPRISING UPTOWN')
# ('NATALIE', 'HOPKINS', 248, 'DOZEN LION')
# ('NATALIE', 'HOPKINS', 303, 'FANTASY TROOPERS')
# ('NATALIE', 'HOPKINS', 372, 'GRACELAND DYNAMITE')
# ('NATALIE', 'HOPKINS', 437, 'HOUSE DYNAMITE')
# ('NATALIE', 'HOPKINS', 504, 'KWAI HOMEWARD')
# ('NATALIE', 'HOPKINS', 520, 'LICENSE WEEKEND')
# ('NATALIE', 'HOPKINS', 632, 'NUTS TIES')
# ('NATALIE', 'HOPKINS', 918, 'TWISTED PIRATES')
# ('GARY', 'PHOENIX', 5, 'AFRICAN EGG')
# ('GARY', 'PHOENIX', 408, 'HEAD STRANGER')
# ('GARY', 'PHOENIX', 461, 'INSECTS STONE')
# ('GARY', 'PHOENIX', 627, 'NORTH TEQUILA')
# ('GARY', 'PHOENIX', 891, 'TIMBERLAND SKY')
# ('GARY', 'PHOENIX', 940, 'VICTORY ACADEMY')
# ('GARY', 'PHOENIX', 990, 'WORLD LEATHERNECKS')
# ('CARMEN', 'HUNT', 20, 'AMELIE HELLFIGHTERS')
# ('CARMEN', 'HUNT', 376, 'GRAPES FURY')
# ('CARMEN', 'HUNT', 388, 'GUNFIGHT MOON')
# ('CARMEN', 'HUNT', 424, 'HOLOCAUST HIGHBALL')
# ('CARMEN', 'HUNT', 474, 'JADE BUNCH')
# ('CARMEN', 'HUNT', 584, 'MIXED DOORS')
# ('CARMEN', 'HUNT', 664, 'PATRIOT ROMAN')
# ('CARMEN', 'HUNT', 675, 'PHANTOM GLORY')
# ('CARMEN', 'HUNT', 951, 'VOYAGE LEGALLY')
# ('CARMEN', 'HUNT', 999, 'ZOOLANDER FICTION')
# ('MENA', 'TEMPLE', 181, 'CONTACT ANONYMOUS')
# ('MENA', 'TEMPLE', 285, 'ENGLISH BULWORTH')
# ('MENA', 'TEMPLE', 307, 'FELLOWSHIP AUTUMN')
# ('MENA', 'TEMPLE', 447, 'ICE CROSSING')
# ('MENA', 'TEMPLE', 465, 'INTERVIEW LIAISONS')
# ('MENA', 'TEMPLE', 577, 'MILE MULAN')
# ('MENA', 'TEMPLE', 727, 'RESURRECTION SILVERADO')
# ('MENA', 'TEMPLE', 947, 'VISION TORQUE')
# ('MENA', 'TEMPLE', 961, 'WASH HEAVENLY')
# ('PENELOPE', 'PINKETT', 129, 'CAUSE DATE')
# ('PENELOPE', 'PINKETT', 184, 'CORE SUIT')
# ('PENELOPE', 'PINKETT', 658, 'PARIS WEEKEND')
# ('FAY', 'KILMER', 8, 'AIRPORT POLLOCK')
# ('FAY', 'KILMER', 75, 'BIRD INDEPENDENCE')
# ('FAY', 'KILMER', 403, 'HARRY IDAHO')
# ('FAY', 'KILMER', 486, 'JET NEIGHBORS')
# ('FAY', 'KILMER', 620, 'NEMO CAMPUS')
# ('FAY', 'KILMER', 776, 'SECRET GROUNDHOG')
# ('DAN', 'HARRIS', 298, 'EYES DRIVING')
# ('DAN', 'HARRIS', 354, 'GHOST GROUNDHOG')
# ('DAN', 'HARRIS', 421, 'HOLIDAY GAMES')
# ('DAN', 'HARRIS', 844, 'STEERS ARMAGEDDON')
# ('DAN', 'HARRIS', 851, 'STRAIGHT HOURS')
# ('JUDE', 'CRUISE', 114, 'CAMELOT VACATION')
# ('JUDE', 'CRUISE', 192, 'CROSSING DIVORCE')
# ('JUDE', 'CRUISE', 592, 'MONSTER SPARTACUS')
# ('JUDE', 'CRUISE', 852, 'STRANGELOVE DESIRE')
# ('CHRISTIAN', 'AKROYD', 48, 'BACKLASH UNDEFEATED')
# ('CHRISTIAN', 'AKROYD', 68, 'BETRAYED REAR')
# ('CHRISTIAN', 'AKROYD', 175, 'CONFUSED CANDLES')
# ('CHRISTIAN', 'AKROYD', 578, 'MILLION ACE')
# ('CHRISTIAN', 'AKROYD', 602, 'MOURNING PURPLE')
# ('CHRISTIAN', 'AKROYD', 638, 'OPERATION OPERATION')
# ('CHRISTIAN', 'AKROYD', 698, 'PRINCESS GIANT')
# ('CHRISTIAN', 'AKROYD', 726, 'RESERVOIR ADAPTATION')
# ('DUSTIN', 'TAUTOU', 46, 'AUTUMN CROW')
# ('DUSTIN', 'TAUTOU', 72, 'BILL OTHERS')
# ('DUSTIN', 'TAUTOU', 130, 'CELEBRITY HORN')
# ('DUSTIN', 'TAUTOU', 183, 'CONVERSATION DOWNHILL')
# ('DUSTIN', 'TAUTOU', 210, 'DARKO DORADO')
# ('DUSTIN', 'TAUTOU', 943, 'VILLAIN DESPERATE')
# ('DUSTIN', 'TAUTOU', 946, 'VIRTUAL SPOILERS')
# ('DUSTIN', 'TAUTOU', 984, 'WONDERFUL DROP')
# ('HENRY', 'BERRY', 297, 'EXTRAORDINARY CONQUERER')
# ('HENRY', 'BERRY', 534, 'LOUISIANA HARRY')
# ('CHRISTIAN', 'NEESON', 237, 'DIVORCE SHINING')
# ('CHRISTIAN', 'NEESON', 362, 'GLORY TRACY')
# ('CHRISTIAN', 'NEESON', 639, 'OPPOSITE NECKLACE')
# ('CHRISTIAN', 'NEESON', 780, 'SENSIBILITY REAR')
# ('JAYNE', 'NEESON', 272, 'EDGE KISSING')
# ('JAYNE', 'NEESON', 406, 'HAUNTING PIANIST')
# ('JAYNE', 'NEESON', 413, 'HEDWIG ALTER')
# ('JAYNE', 'NEESON', 719, 'RECORDS ZORRO')
# ('CAMERON', 'WRAY', 167, 'COMA HEAD')
# ('CAMERON', 'WRAY', 278, 'ELF MURDER')
# ('CAMERON', 'WRAY', 763, 'SATISFACTION CONFIDENTIAL')
# ('CAMERON', 'WRAY', 809, 'SLIPPER FIDELITY')
# ('RAY', 'JOHANSSON', 471, 'ISLAND EXORCIST')
# ('RAY', 'JOHANSSON', 543, 'MADIGAN DORADO')
# ('RAY', 'JOHANSSON', 557, 'MANCHURIAN CURTAIN')
# ('RAY', 'JOHANSSON', 860, 'SUICIDES SILENCE')
# ('RAY', 'JOHANSSON', 921, 'UNCUT SUICIDES')
# ('ANGELA', 'HUDSON', 39, 'ARMAGEDDON LOST')
# ('ANGELA', 'HUDSON', 97, 'BRIDE INTRIGUE')
# ('ANGELA', 'HUDSON', 371, 'GOSFORD DONNIE')
# ('ANGELA', 'HUDSON', 496, 'KICK SAVANNAH')
# ('ANGELA', 'HUDSON', 556, 'MALTESE HOPE')
# ('MARY', 'TANDY', 55, 'BARBARELLA STREETCAR')
# ('MARY', 'TANDY', 143, 'CHILL LUCK')
# ('MARY', 'TANDY', 229, 'DEVIL DESIRE')
# ('MARY', 'TANDY', 300, 'FALCON VOLUME')
# ('MARY', 'TANDY', 350, 'GARDEN ISLAND')
# ('MARY', 'TANDY', 676, 'PHILADELPHIA WIFE')
# ('MARY', 'TANDY', 706, 'QUEEN LUKE')
# ('MARY', 'TANDY', 960, 'WARS PLUTO')
# ('JESSICA', 'BAILEY', 57, 'BASIC EASY')
# ('JESSICA', 'BAILEY', 512, 'LEAGUE HELLFIGHTERS')
# ('JESSICA', 'BAILEY', 601, 'MOULIN WAKE')
# ('JESSICA', 'BAILEY', 870, 'SWARM GOLD')
# ('RIP', 'WINSLET', 215, 'DAWN POND')
# ('RIP', 'WINSLET', 325, 'FLOATS GARDEN')
# ('RIP', 'WINSLET', 331, 'FORWARD TEMPLE')
# ('RIP', 'WINSLET', 607, 'MUPPET MILE')
# ('RIP', 'WINSLET', 654, 'PANKY SUBMARINE')
# ('RIP', 'WINSLET', 834, 'SPOILERS HELLFIGHTERS')
# ('KENNETH', 'PALTROW', 452, 'ILLUSION AMELIE')
# ('KENNETH', 'PALTROW', 761, 'SANTA PARIS')
# ('KENNETH', 'PALTROW', 791, 'SHOW LORD')
# ('KENNETH', 'PALTROW', 864, 'SUNDANCE INVASION')
# ('MICHELLE', 'MCCONAUGHEY', 50, 'BAKED CLEOPATRA')
# ('MICHELLE', 'MCCONAUGHEY', 227, 'DETAILS PACKER')
# ('MICHELLE', 'MCCONAUGHEY', 304, 'FARGO GANDHI')
# ('MICHELLE', 'MCCONAUGHEY', 343, 'FULL FLATLINERS')
# ('MICHELLE', 'MCCONAUGHEY', 628, 'NORTHWEST POLISH')
# ('MICHELLE', 'MCCONAUGHEY', 823, 'SOUTH WAIT')
# ('ADAM', 'GRANT', 26, 'ANNIE IDENTITY')
# ('ADAM', 'GRANT', 560, 'MARS ROMAN')
# ('ADAM', 'GRANT', 773, 'SEABISCUIT PUNK')
# ('SEAN', 'WILLIAMS', 609, 'MUSCLE BRIGHT')
# ('SEAN', 'WILLIAMS', 623, 'NEWTON LABYRINTH')
# ('SEAN', 'WILLIAMS', 640, 'OPUS ICE')
# ('GARY', 'PENN', 562, 'MASKED BUBBLE')
# ('GARY', 'PENN', 666, 'PAYCHECK WAIT')
# ('MILLA', 'KEITEL', 28, 'ANTHEM LUKE')
# ('MILLA', 'KEITEL', 617, 'NATURAL STOCK')
# ('MILLA', 'KEITEL', 848, 'STONE FIRE')
# ('MILLA', 'KEITEL', 872, 'SWEET BROTHERHOOD')
# ('BURT', 'POSEY', 446, 'HYSTERICAL GRAIL')
# ('BURT', 'POSEY', 498, 'KILLER INNOCENT')
# ('ANGELINA', 'ASTAIRE', 95, 'BREAKFAST GOLDFINGER')
# ('ANGELINA', 'ASTAIRE', 234, 'DISTURBING SCARFACE')
# ('ANGELINA', 'ASTAIRE', 464, 'INTENTIONS EMPIRE')
# ('ANGELINA', 'ASTAIRE', 642, 'ORDER BETRAYED')
# ('ANGELINA', 'ASTAIRE', 760, 'SAMURAI LION')
# ('ANGELINA', 'ASTAIRE', 765, 'SATURN NAME')
# ('ANGELINA', 'ASTAIRE', 866, 'SUNSET RACER')
# ('CARY', 'MCCONAUGHEY', 13, 'ALI FOREVER')
# ('CARY', 'MCCONAUGHEY', 22, 'AMISTAD MIDSUMMER')
# ('CARY', 'MCCONAUGHEY', 224, 'DESPERATE TRAINSPOTTING')
# ('CARY', 'MCCONAUGHEY', 240, 'DOLLS RAGE')
# ('CARY', 'MCCONAUGHEY', 261, 'DUFFEL APOCALYPSE')
# ('CARY', 'MCCONAUGHEY', 442, 'HUNTING MUSKETEERS')
# ('CARY', 'MCCONAUGHEY', 566, 'MAUDE MOD')
# ('GROUCHO', 'SINATRA', 265, 'DYING MAKER')
# ('GROUCHO', 'SINATRA', 762, 'SASSY PACKER')
# ('MAE', 'HOFFMAN', 32, 'APOCALYPSE FLAMINGOS')
# ('MAE', 'HOFFMAN', 33, 'APOLLO TEEN')
# ('MAE', 'HOFFMAN', 141, 'CHICAGO NORTH')
# ('MAE', 'HOFFMAN', 916, 'TURN STAR')
# ('RALPH', 'CRUZ', 622, 'NEWSIES STORY')
# ('RALPH', 'CRUZ', 807, 'SLEUTH ORIENT')
# ('RALPH', 'CRUZ', 941, 'VIDEOTAPE ARSENIC')
# ('RALPH', 'CRUZ', 979, 'WITCHES PANIC')
# ('SCARLETT', 'DAMON', 59, 'BEAR GRACELAND')
# ('SCARLETT', 'DAMON', 332, 'FRANKENSTEIN STRANGER')
# ('SCARLETT', 'DAMON', 613, 'MYSTIC TRUMAN')
# ('SCARLETT', 'DAMON', 710, 'RAGE GAMES')
# ('WOODY', 'JOLIE', 104, 'BUGSY SONG')
# ('WOODY', 'JOLIE', 247, 'DOWNHILL ENOUGH')
# ('WOODY', 'JOLIE', 468, 'INVASION CYCLONE')
# ('WOODY', 'JOLIE', 911, 'TRIP NEWTON')
# ('WOODY', 'JOLIE', 954, 'WAKE JAWS')
# ('BEN', 'WILLIS', 49, 'BADMAN DAWN')
# ('BEN', 'WILLIS', 120, 'CARIBBEAN LIBERTY')
# ('BEN', 'WILLIS', 339, 'FROGMEN BREAKING')
# ('BEN', 'WILLIS', 412, 'HEAVYWEIGHTS BEAST')
# ('BEN', 'WILLIS', 655, 'PANTHER REDS')
# ('JAMES', 'PITT', 238, 'DOCTOR GRAIL')
# ('JAMES', 'PITT', 479, 'JEDI BENEATH')
# ('MINNIE', 'ZELLWEGER', 630, 'NOTTING SPEAKEASY')
# ('GREG', 'CHAPLIN', 137, 'CHARADE DUFFEL')
# ('GREG', 'CHAPLIN', 196, 'CRUELTY UNFORGIVEN')
# ('GREG', 'CHAPLIN', 432, 'HOPE TOOTSIE')
# ('GREG', 'CHAPLIN', 857, 'STRICTLY SCARFACE')
# ('GREG', 'CHAPLIN', 905, 'TRAINSPOTTING STRANGERS')
# ('SPENCER', 'PECK', 157, 'CLOCKWORK PARADISE')
# ('KENNETH', 'PESCI', 76, 'BIRDCAGE CASPER')
# ('KENNETH', 'PESCI', 819, 'SONG HEDWIG')
# ('CHARLIZE', 'DENCH', 976, 'WIND PHANTOM')
# ('SEAN', 'GUINESS', 363, 'GO PURPLE')
# ('SEAN', 'GUINESS', 384, 'GROSSE WONDERFUL')
# ('CHRISTOPHER', 'BERRY', 190, 'CREEPERS KANE')
# ('CHRISTOPHER', 'BERRY', 511, 'LAWRENCE LOVE')
# ('CHRISTOPHER', 'BERRY', 849, 'STORM HAPPINESS')
# ('KIRSTEN', 'AKROYD', 123, 'CASABLANCA SUPER')
# ('KIRSTEN', 'AKROYD', 443, 'HURRICANE AFFAIR')
# ('KIRSTEN', 'AKROYD', 470, 'ISHTAR ROCKETEER')
# ('KENNETH', 'TORN', 206, 'DANCING FEVER')
# ('KENNETH', 'TORN', 228, 'DETECTIVE VISION')
# ('KENNETH', 'TORN', 270, 'EARTH VISION')
# ('KENNETH', 'TORN', 402, 'HARPER DYING')
# ('DARYL', 'WAHLBERG', 690, 'POND SEATTLE')
# ('DARYL', 'WAHLBERG', 813, 'SMOOCHY CONTROL')
# ('DARYL', 'WAHLBERG', 828, 'SPIKING ELEMENT')
# ('GENE', 'WILLIS', 209, 'DARKNESS WAR')
# ('GENE', 'WILLIS', 661, 'PAST SUICIDES')
# ('GENE', 'WILLIS', 987, 'WORDS HUNTER')
# ('MEG', 'HAWKE', 641, 'ORANGE GRAPES')
# ('MEG', 'HAWKE', 656, 'PAPI NECKLACE')
# ('CHRIS', 'BRIDGES', 824, 'SPARTACUS CHEAPER')
# ('CHRIS', 'BRIDGES', 955, 'WALLS ARTIST')
# ('JIM', 'MOSTEL', 7, 'AIRPLANE SIERRA')
# ('JIM', 'MOSTEL', 741, 'ROMAN PUNK')
# ('JIM', 'MOSTEL', 796, 'SIERRA DIVIDE')
# ('SPENCER', 'DEPP', 563, 'MASSACRE USUAL')
# ('SPENCER', 'DEPP', 992, 'WRATH MILE')
# ('SUSAN', 'DAVIS', 189, 'CREATURES SHAKESPEARE')
# ('SUSAN', 'DAVIS', 774, 'SEARCHERS WAIT')
# ('WALTER', 'TORN', 526, 'LOCK REAR')
# ('WALTER', 'TORN', 624, 'NIGHTMARE CHILL')
# ('WALTER', 'TORN', 837, 'STAGE WORLD')
# ('WALTER', 'TORN', 845, 'STEPMOM DREAM')
# ('MATTHEW', 'LEIGH', 356, 'GIANT TROOPERS')
# ('MATTHEW', 'LEIGH', 360, 'GLASS DYING')
# ('MATTHEW', 'LEIGH', 822, 'SOUP WISDOM')
# ('PENELOPE', 'CRONYN', 156, 'CLERKS ANGELS')
# ('PENELOPE', 'CRONYN', 677, 'PIANIST OUTFIELD')
# ('GROUCHO', 'DUNST', 365, 'GOLD RIVER')
# ('GROUCHO', 'DUNST', 439, 'HUNCHBACK IMPOSSIBLE')
# ('GROUCHO', 'DUNST', 659, 'PARK CITIZEN')
# ('GROUCHO', 'DUNST', 934, 'VANILLA DAY')
# ('GINA', 'DEGENERES', 138, 'CHARIOTS CONSPIRACY')
# ('GINA', 'DEGENERES', 220, 'DEER VIRGINIAN')
# ('GINA', 'DEGENERES', 409, 'HEARTBREAKERS BRIGHT')
# ('WARREN', 'NOLTE', 302, 'FANTASIA PARK')
# ('WARREN', 'NOLTE', 693, 'POTTER CONNECTICUT')
# ('SYLVESTER', 'DERN', 786, 'SHEPHERD MIDSUMMER')
# ('SUSAN', 'DAVIS', 801, 'SISTER FREDDY')
# ('CAMERON', 'ZELLWEGER', 61, 'BEAUTY GREASE')
# ('CAMERON', 'ZELLWEGER', 98, 'BRIGHT ENCOUNTERS')
# ('CAMERON', 'ZELLWEGER', 382, 'GRIT CLOCKWORK')
# ('HARRISON', 'BALE', 246, 'DOUBTFIRE LABYRINTH')
# ('HARRISON', 'BALE', 740, 'ROLLERCOASTER BRINGING')
# ('DAN', 'STREEP', 647, 'OUTFIELD MASSACRE')
# ('RENEE', 'TRACY', 459, 'INFORMER DOUBLE')
# ('CUBA', 'ALLEN', 41, 'ARSENIC INDEPENDENCE')
# ('WARREN', 'JACKMAN', 614, 'NAME DETECTIVE')
# ('PENELOPE', 'MONROE', 149, 'CHRISTMAS MOONSHINE')
# ('PENELOPE', 'MONROE', 746, 'ROUGE SQUAD')
# ('PENELOPE', 'MONROE', 898, 'TOURIST PELICAN')
# ('LIZA', 'BERGMAN', 884, 'TERMINATOR CLUB')
# ('SCARLETT', 'BENING', 113, 'CALIFORNIA BIRDS')
# ('SCARLETT', 'BENING', 814, 'SNATCH SLIPPER')
# ('SCARLETT', 'BENING', 882, 'TENENBAUMS COMMAND')
# ('ALBERT', 'NOLTE', 324, 'FLINTSTONES HAPPINESS')
# ('CATE', 'MCQUEEN', 82, 'BLOOD ARGONAUTS')
# ('CATE', 'MCQUEEN', 899, 'TOWERS HURRICANE')
# ('DARYL', 'CRAWFORD', 684, 'PIZZA JUMANJI')
# ('RICHARD', 'PENN', 397, 'HANKY OCTOBER')
# ('ED', 'MANSFIELD', 818, 'SOMETHING DUCK')
# ('MORGAN', 'WILLIAMS', 610, 'MUSIC BOONDOCK')
# ('EWAN', 'GOODING', 373, 'GRADUATE LORD')
# ('JADA', 'RYDER', 328, 'FOREVER CANDIDATE')
# ('JADA', 'RYDER', 575, 'MIDSUMMER GROUNDHOG')
# ('RIVER', 'DEAN', 660, 'PARTY KNOCK')
# ('KIM', 'ALLEN', 487, 'JINGLE SAGEBRUSH')
# ('KIM', 'ALLEN', 629, 'NOTORIOUS REUNION')
# ('FAY', 'WINSLET', 708, 'QUILLS BULL')
# ('EMILY', 'DEE', 422, 'HOLLOW JEOPARDY')
# ('RUSSELL', 'TEMPLE', 169, 'COMFORTS RUSH')
# ('BEN', 'HARRIS', 611, 'MUSKETEERS WAIT')
# ('MERYL', 'GIBSON', 440, 'HUNGER ROOF')
# ('IAN', 'TANDY', 1000, 'ZORRO ARK')
# ('VIVIEN', 'BASINGER', 102, 'BUBBLE GROSSE')
# ('VIVIEN', 'BASINGER', 581, 'MINORITY KISS')
# ('LAURA', 'BRODY', 789, 'SHOCK CABIN')
# ('HUMPHREY', 'WILLIS', 681, 'PIRATES ROXANNE')
# ('NICK', 'DEGENERES', 580, 'MINE TITANS')
# ('OLYMPIA', 'PFEIFFER', 701, 'PSYCHO SHRUNK')
# ('MICHAEL', 'BENING', 352, 'GATHERING CALENDAR')
# ('REESE', 'WEST', 995, 'YENTL IDAHO')
# ('MARY', 'KEITEL', 264, 'DWARFS ALTER')

# %%
db('''
SELECT
    title
FROM
    film
    INNER JOIN film_actor USING (film_id)
    INNER JOIN actor USING (actor_id)
WHERE
    LEFT(title, 1) = LEFT(first_name, 1)
GROUP BY
    film_id
HAVING
    COUNT(actor_id) > 2
''')
# Out:
# Executando query:
# ('CROW GREASE',)
# ('JEDI BENEATH',)
# ('SUBMARINE BED',)

# %% [markdown]
# Semana do "DAN HARRIS": liste os clientes que nunca assistiram um filme do ator "DAN HARRIS" ou que já assistiram mas onde a ultima vez em que assistiram um filme dele foi antes de '2005-06-01'

# %%
db('DROP TABLE IF EXISTS films_dan')
db('''
CREATE TEMPORARY TABLE films_dan
    SELECT DISTINCT
        film_id
    FROM
        film_actor 
        INNER JOIN actor USING (actor_id)
    WHERE
        first_name = "DAN" AND last_name = "HARRIS"
    ORDER BY
        film_id
''')
db('SELECT * FROM films_dan')
# Out:
# Executando query:
# Executando query:
# Executando query:
# (63,)
# (87,)
# (226,)
# (236,)
# (298,)
# (307,)
# (354,)
# (383,)
# (417,)
# (421,)
# (457,)
# (462,)
# (474,)
# (521,)
# (593,)
# (728,)
# (750,)
# (769,)
# (781,)
# (795,)
# (844,)
# (851,)
# (862,)
# (868,)
# (892,)
# (893,)
# (936,)
# (965,)

# %%
db('''
SELECT
    COUNT(DISTINCT customer_id)
FROM
    customer
    LEFT OUTER JOIN rental USING (customer_id)
    LEFT OUTER JOIN inventory USING (inventory_id)
    LEFT OUTER JOIN films_dan USING (film_id)
WHERE
    films_dan.film_id IS NULL
''')
# Out:
# Executando query:
# (599,)

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Façamos uma pausa para apreciar quão longe estamos: já conseguimos criar nossas tabelas, inserir informação, removê-la, atualizá-la, e consultar nossa base de maneiras bem sofisticadas! Vimos desde `SELECT` simples até buscas mais complexas envolvendo várias etapas de processamento para obter o dado desejado.
#
# Por hoje é só, feche sua conexão e bom descanso!

# %%
connection.close()
